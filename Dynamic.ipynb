# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math
# %matplotlib inline

# %%
def person():
    genre = ['h','f'] ; f=False
    X = random.randint(0,100)
    Y = random.randint(0,100)
    g = genre[math.floor(2*random.random())]
    nb_age = random.random()
    if nb_age<0.16 :
        Age = random.randint(15,29)
    elif nb_age<0.3925 :
        Age = random.randint(30,39)
    elif nb_age<0.635 :
        Age = random.randint(40,49)
    elif nb_age<0.8275 :
        Age = random.randint(50,59)
    else :
        Age = random.randint(60,80)
    nb_sp = random.random() ; sp = 'N'
    if Age<18 :
        sp = 'ado'
    else :
        if nb_sp<0.09 :
            sp = 'chomeur'
        if sp == 'N' :
            nb_sp = random.random()
            if 18<=Age<=24 :
                if nb_sp<0.5 :
                    sp = 'etu'
            elif Age<=29 :
                if 0.5<=nb_sp<0.56 :
                    sp = 'etu'
            if sp == 'N' :
                if g == 'h' :
                    if Age<30 :
                        if nb_sp<0.01 :
                            sp = 'agri'
                        elif nb_sp<0.03 :
                            sp = 'ceo'
                        elif nb_sp<0.14 :
                            sp = 'cadre'
                        elif nb_sp<0.34 :
                            sp = 'pro_interm'
                        elif nb_sp<0.51 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<40 :
                        if nb_sp<0.04 :
                            sp = 'agri'
                        elif nb_sp<0.1 :
                            sp = 'ceo'
                        elif nb_sp<0.26 :
                            sp = 'cadre'
                        elif nb_sp<0.47 :
                            sp = 'pro_interm'
                        elif nb_sp<0.61 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<50 :
                        if nb_sp<0.04 :
                            sp = 'agri'
                        elif nb_sp<0.12 :
                            sp = 'ceo'
                        elif nb_sp<0.27 :
                            sp = 'cadre'
                        elif nb_sp<0.49 :
                            sp = 'pro_interm'
                        elif nb_sp<0.62 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<60 :
                        if nb_sp<0.05 :
                            sp = 'agri'
                        elif nb_sp<0.16 :
                            sp = 'ceo'
                        elif nb_sp<0.36 :
                            sp = 'cadre'
                        elif nb_sp<0.6 :
                            sp = 'pro_interm'
                        elif nb_sp<0.69 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<66 :
                        if nb_sp<0.1 :
                            sp = 'agri'
                        elif nb_sp<0.22 :
                            sp = 'ceo'
                        elif nb_sp<0.39 :
                            sp = 'cadre'
                        elif nb_sp<0.6 :
                            sp = 'pro_interm'
                        elif nb_sp<0.69 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    else : 
                        sp = 'retraite'
                else :
                    if Age<30 :
                        if nb_sp<0.002 :
                            sp = 'agri'
                        elif nb_sp<0.012 :
                            sp = 'ceo'
                        elif nb_sp<0.092 :
                            sp = 'cadre'
                        elif nb_sp<0.312 :
                            sp = 'pro_interm'
                        elif nb_sp<0.832 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<40 :
                        if nb_sp<0.01 :
                            sp = 'agri'
                        elif nb_sp<0.03 :
                            sp = 'ceo'
                        elif nb_sp<0.14 :
                            sp = 'cadre'
                        elif nb_sp<0.35 :
                            sp = 'pro_interm'
                        elif nb_sp<0.86 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<50 :
                        if nb_sp<0.02 :
                            sp = 'agri'
                        elif nb_sp<0.06 :
                            sp = 'ceo'
                        elif nb_sp<0.15 :
                            sp = 'cadre'
                        elif nb_sp<0.36 :
                            sp = 'pro_interm'
                        elif nb_sp<0.85 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<60 :
                        if nb_sp<0.03 :
                            sp = 'agri'
                        elif nb_sp<0.08 :
                            sp = 'ceo'
                        elif nb_sp<0.2 :
                            sp = 'cadre'
                        elif nb_sp<0.41 :
                            sp = 'pro_interm'
                        elif nb_sp<0.84 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<66 :
                        if nb_sp<0.1 :
                            sp = 'agri'
                        elif nb_sp<0.19 :
                            sp = 'ceo'
                        elif nb_sp<0.25 :
                            sp = 'cadre'
                        elif nb_sp<0.39 :
                            sp = 'pro_interm'
                        elif nb_sp<0.8 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    else : 
                        sp = 'retraite'
    nb_c = random.random()
    if Age<30 :
        if nb_c<0.01 :
            c = 'ill'
        else :
            c = 'healthy'
    elif Age<50 :
        nb_c = random.random()
        if nb_c<0.1 :
            c = 'ill'
        else :
            c = 'healthy'
    elif Age<65 :
        nb_c = random.random()
        if nb_c<0.4 :
            c = 'ill'
        else : 
            c = 'healthy'
    else :
        nb_c = random.random()
        if nb_c<0.7 :
            c = 'ill'
        else : 
            c = 'healthy'
    
    if sp == 'ceo' or sp == 'cadre':
        if c == 'healthy':
            if g == 'h':
                fume = random.random()
                if fume<0.094:
                    f = True
            else :
                fume = random.random()
                if fume<0.074: 
                    f = True
        else :
            if g == 'h':
                fume = random.random()
                if fume<0.05:
                    f = True
            else :
                fume = random.random()
                if fume<0.03:
                    f = True
    elif sp == 'chomeur' and Age<55 :
        if g == 'h':
            n = random.random()
            if n<0.564:
                f=True
        else :
            n = random.random()
            if n<0.454:
                f=True
    elif sp == 'chomeur' and Age>=55 :
        n = random.random()
        if n<0.205:
            f=True
    else :
        if f == False :
            nb_f = random.random()
            if Age<20 :
                l = 0.39 
                if c == 'ill' :
                    l = l/2 
                    if nb_f<l :
                        f = True
                else :
                    l = 1.2*l
                    if nb_f<l :
                        f = True

            elif Age<26 :
                nb_f = random.random()
                l = 0.45
                if c == 'ill' :
                    l = l/3
                    if nb_f<l :
                        f = True
                else :
                    l = 1.2*l
                    if nb_f<l :
                        f = True     
            elif Age<50 :
                nb_f = random.random()
                l = 0.27
                if c == 'ill' :
                    l = l/3 
                    if nb_f<l :
                        f = True
                else :
                    l = 1.1*l
                    if nb_f<l :
                        f = True
            elif Age<60 :
                if g == 'h':
                    nb_f = random.random()
                    l = 0.17
                    if c == 'ill' :
                        l = l/7
                        if nb_f<l :
                            f = True
                    else :
                        l = 1.2*l
                        if nb_f<l :
                            f = True
                else :
                    nb_f = random.random()
                    l = 0.08
                    if c == 'ill' :
                        l = l/8 
                        if nb_f<l :
                            f = True
                    else :
                        l = 1.3*l
                        if nb_f<l :
                            f = True
            else :
                if g == 'h':
                    nb_f = random.random()
                    l = 0.12
                    if c == 'ill' :
                        l = l/7
                        if nb_f<l :
                            f = True
                    else :
                        l = 2*l
                        if nb_f<l :
                            f = True
                else :
                    nb_f = random.random()
                    l = 0.05
                    if c == 'ill' :
                        l = l/10 
                        if nb_f<l :
                            f = True
                    else :
                        l = 1.2*l
                        if nb_f<l :
                              f = True       
    if f :
        color = 'red'
    else : 
        color = 'white'
    nb_essai_arret = 0 ; nb_pub = 0 ; nb_lutte = 0   
           
    return [X,Y,color,Age,g,sp,c,nb_essai_arret,nb_pub,nb_lutte,f]

# %%
def create_pop(n):
    pop = []
    for i in range (n) :
        pop.append(person())
    return pop

pop = create_pop(10)

# %%
def proche(pop):
    proche = []
    for i in range (len(pop)):
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        dist = [np.sqrt((x_val[i] - x[0])**2 + (y_val[i] - x[1])**2) for x in pop]
        p_i = [dist.index(j) for j in dist if j < 3]
        proche.append(p_i)
    return proche

pop = [[13, 12, 'white', 35, 'h', 'ouvrier', 'healthy', False], \
    [14, 12, 'white', 20, 'f', 'employe', 'healthy', False], \
    [14, 11, 'red', 25, 'h', 'chomeur', 'healthy', True], \
    [45, 60, 'white', 76, 'h', 'retraite', 'healthy', False], [56, 67, 'red', 72, 'h', 'retraite', 'healthy', True]]

print(pop)
print("\n")  
print(proche(pop))

i=0
tmp=[]
while i<len(proche(pop)) :
    if len(proche(pop)[i])>1 :
        if i not in tmp :
            for b in range(1,len(proche(pop)[i])) :
                tmp.append(b)
            for j in proche(pop)[i]:
                change=[]
                if pop[j][-1]:
                    for a in proche(pop)[i]:
                        if pop[a][-1]==False :
                            change.append(a)
            fume = random.random()
            if fume<0.3 :
                pop[math.floor(len(change)*random.random())][-1]=True
    i=i+1

print("\n")                
print(pop)
# Out:
# [[13, 12, 'white', 35, 'h', 'ouvrier', 'healthy', False], [14, 12, 'white', 20, 'f', 'employe', 'healthy', False], [14, 11, 'red', 25, 'h', 'chomeur', 'healthy', True], [45, 60, 'white', 76, 'h', 'retraite', 'healthy', False], [56, 67, 'red', 72, 'h', 'retraite', 'healthy', True]]
#
#
# [[0, 1, 2], [0, 1, 0], [0, 1, 2], [3], [4]]
#
#
# [[13, 12, 'white', 35, 'h', 'ouvrier', 'healthy', False], [14, 12, 'white', 20, 'f', 'employe', 'healthy', False], [14, 11, 'red', 25, 'h', 'chomeur', 'healthy', True], [45, 60, 'white', 76, 'h', 'retraite', 'healthy', False], [56, 67, 'red', 72, 'h', 'retraite', 'healthy', True]]

# %%
def debute_age_sponta(pop):  #chaque année
    for i in range(len(pop)) :
        if pop[i][-4]<4:
            if 15<=pop[i][3]<=30 :
                if pop[i][-1]==False :
                    fume = random.random()
                    if fume<0.4 :
                        pop[i][-1]=True
                        pop[i][2]='red'
                        ar = random.random()
                        if ar<0.65:
                            pop[i][-1]=False
                            pop[i][2]='white'
                    
                    
            else :
                if pop[4]=='h':
                    if pop[i][-1]==False and pop[i][6]=='healthy' :
                        fume = random.random()
                        if fume<0.2 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                            ar = random.random()
                            if ar<0.55:
                                pop[i][-1]=False
                                pop[i][2]='white'
                else :
                    if pop[i][-1]==False and pop[i][6]=='healthy' :
                        fume = random.random()
                        if fume<0.15 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                            ar = random.random()
                            if ar<0.5:
                                pop[i][-1]=False
                                pop[i][2]='white'
                            
pop = [[13, 12, 'white', 35, 'h', 'ouvrier', 'healthy', 0, 0, 0, False], \
    [14, 12, 'white', 20, 'f', 'employe', 'healthy', 0, 0, 0, False], \
    [14, 11, 'red', 25, 'h', 'chomeur', 'healthy', 0, 0, 0, True], \
    [45, 60, 'white', 76, 'h', 'retraite', 'healthy', 0, 0, 0, False], [56, 67, 'red', 72, 'h', 'retraite', 'healthy', 0, 0, 0, True]]

debute_age_sponta(pop)

print(pop)
# Out:
# [[13, 12, 'white', 35, 'h', 'ouvrier', 'healthy', 0, 0, 0, False], [14, 12, 'white', 20, 'f', 'employe', 'healthy', 0, 0, 0, False], [14, 11, 'red', 25, 'h', 'chomeur', 'healthy', 0, 0, 0, True], [45, 60, 'white', 76, 'h', 'retraite', 'healthy', 0, 0, 0, False], [56, 67, 'red', 72, 'h', 'retraite', 'healthy', 0, 0, 0, True]]

# %%
def arret_reprise_sponta(pop): #chaque année
    for i in range(len(pop)) :
        if pop[i][-1]:
            if pop[i][-4]<4:
                if pop[i][6]=='ill' :
                    n = random.random()
                    if n<0.5 : #arrêt d'un an au moins, on peut considérer 
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        reprise = random.random()
                        if reprise<0.45 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                        else :
                            pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre 
                else :
                    if pop[i][5]=='ceo' or pop[i][5]=='cadre' or pop[i][3]>50 :
                        n = random.random()
                        if n<0.1 : #arrêt d'un an au moins, on peut considérer 
                            pop[i][-4]=pop[i][-4]+1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.6 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                            else :
                                pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre
                    else :
                        n = random.random()
                        if n<0.045 : #arrêt d'un an au moins, on peut considérer 
                            pop[i][-4]=pop[i][-4]+1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.7 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                            else :
                                pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre
                    
        
pop = create_pop(20)
print(pop)
arret_reprise_sponta(pop)
print(pop)
# Out:
# [[56, 42, 'red', 25, 'h', 'ouvrier', 'healthy', 0, 0, 0, True], [59, 13, 'white', 45, 'f', 'employe', 'healthy', 0, 0, 0, False], [67, 92, 'red', 22, 'f', 'etu', 'healthy', 0, 0, 0, True], [3, 37, 'white', 35, 'f', 'pro_interm', 'healthy', 0, 0, 0, False], [81, 52, 'white', 35, 'f', 'pro_interm', 'healthy', 0, 0, 0, False], [1, 83, 'white', 77, 'h', 'retraite', 'ill', 0, 0, 0, False], [4, 96, 'red', 25, 'f', 'ouvrier', 'healthy', 0, 0, 0, True], [11, 76, 'white', 70, 'h', 'retraite', 'ill', 0, 0, 0, False], [33, 68, 'white', 51, 'h', 'pro_interm', 'healthy', 0, 0, 0, False], [39, 98, 'red', 38, 'h', 'ouvrier', 'healthy', 0, 0, 0, True], [56, 75, 'white', 39, 'f', 'employe', 'healthy', 0, 0, 0, False], [37, 57, 'white', 37, 'f', 'employe', 'healthy', 0, 0, 0, False], [56, 41, 'red', 76, 'h', 'retraite', 'healthy', 0, 0, 0, True], [15, 96, 'white', 22, 'f', 'etu', 'healthy', 0, 0, 0, False], [76, 12, 'white', 47, 'f', 'chomeur', 'healthy', 0, 0, 0, False], [10, 17, 'white', 28, 'f', 'etu', 'healthy', 0, 0, 0, False], [26, 81, 'white', 66, 'f', 'retraite', 'ill', 0, 0, 0, False], [30, 4, 'white', 61, 'f', 'ceo', 'ill', 0, 0, 0, False], [58, 76, 'white', 77, 'h', 'retraite', 'ill', 0, 0, 0, False], [41, 11, 'white', 39, 'f', 'employe', 'healthy', 0, 0, 0, False]]
# [[56, 42, 'red', 25, 'h', 'ouvrier', 'healthy', 0, 0, 0, True], [59, 13, 'white', 45, 'f', 'employe', 'healthy', 0, 0, 0, False], [67, 92, 'red', 22, 'f', 'etu', 'healthy', 0, 0, 0, True], [3, 37, 'white', 35, 'f', 'pro_interm', 'healthy', 0, 0, 0, False], [81, 52, 'white', 35, 'f', 'pro_interm', 'healthy', 0, 0, 0, False], [1, 83, 'white', 77, 'h', 'retraite', 'ill', 0, 0, 0, False], [4, 96, 'red', 25, 'f', 'ouvrier', 'healthy', 0, 0, 0, True], [11, 76, 'white', 70, 'h', 'retraite', 'ill', 0, 0, 0, False], [33, 68, 'white', 51, 'h', 'pro_interm', 'healthy', 0, 0, 0, False], [39, 98, 'red', 38, 'h', 'ouvrier', 'healthy', 0, 0, 0, True], [56, 75, 'white', 39, 'f', 'employe', 'healthy', 0, 0, 0, False], [37, 57, 'white', 37, 'f', 'employe', 'healthy', 0, 0, 0, False], [56, 41, 'red', 76, 'h', 'retraite', 'healthy', 0, 0, 0, True], [15, 96, 'white', 22, 'f', 'etu', 'healthy', 0, 0, 0, False], [76, 12, 'white', 47, 'f', 'chomeur', 'healthy', 0, 0, 0, False], [10, 17, 'white', 28, 'f', 'etu', 'healthy', 0, 0, 0, False], [26, 81, 'white', 66, 'f', 'retraite', 'ill', 0, 0, 0, False], [30, 4, 'white', 61, 'f', 'ceo', 'ill', 0, 0, 0, False], [58, 76, 'white', 77, 'h', 'retraite', 'ill', 0, 0, 0, False], [41, 11, 'white', 39, 'f', 'employe', 'healthy', 0, 0, 0, False]]

# %%
def diffu_lutte(pop):
    for i in range(len(pop)) :
        if pop[i][3]<41 :
            l = 6
        else :
            l = 10
        vu = random.random()
        if pop[i][-2]<l:
            if vu<0.25:
                pop[i][-2]=pop[i][-2]+1
        if pop[i][-4]<4 :
            if pop[i][-1]:
                n = random.random()
                if pop[i][-2]>=l/2:
                    if n<0.65 :
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        reprise = random.random()
                        if pop[i][-4]<4 :
                            if reprise<0.4 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                else :
                    if n<0.3 :
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        reprise = random.random()
                        if pop[i][-4]<4 :
                            if reprise<0.7 :
                                pop[i][-1]=True
                                pop[i][2]='red'

# %%
def diffu_pub(pop):
    radio = random.random()
    tv = random.random()
    reseau = random.random() 
    n = random.random()
    for i in range(len(pop)) :
        if pop[i][3]<41 :
            l = 6
        else :
            l = 10
        if pop[i][-2]<l:
            if radio<0.3:
                pop[i][-3]=pop[i][-3]+1
            if tv<0.25:
                pop[i][-3]=pop[i][-3]+1
            if pop[i][3]<60:
                if reseau<0.8:
                    pop[i][-3]=pop[i][-3]+1
            else:
                if reseau<0.2:
                    pop[i][-3]=pop[i][-3]+1
        if pop[i][-4]<4 :
            if pop[i][-1]==False:
                if pop[i][-3]>=l/2:
                    if n<0.11 :
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=True
                        pop[i][2]='red'
                else :
                    if n<0.05 :
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=True
                        pop[i][2]='red'

# %%
def pop_init(pop):
    debute_age_sponta(pop)
    arret_reprise_sponta(pop)
    diffu_lutte(pop)
    diffu_pub(pop)
    x_val = [x[0] for x in pop]
    y_val = [x[1] for x in pop]
    color = [x[2] for x in pop]
            
    plt.scatter(x_val,y_val, c = color, alpha = 0.7, edgecolors = 'black')
    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)

    plt.xlim(0,100)
    plt.ylim(0,100)
    plt.show()
    
    return pop

pop = create_pop(1000)

pop_init(pop)

def compte(pop):
    r = 0
    for i in range(len(pop)):
        if pop[i][-1]:
            r = r+1
    return r

print(compte(pop))
pop_init(pop)
print(compte(pop))
pop_init(pop)
pop_init(pop)
pop_init(pop)
print(compte(pop))
pop_init(pop)
pop_init(pop)
pop_init(pop)
print(compte(pop))
pop_init(pop)
pop_init(pop)
pop_init(pop)
pop_init(pop)
pop_init(pop)
pop_init(pop)
print(compte(pop))
pop_init(pop)
pop_init(pop)
print(compte(pop))
pop_init(pop)
pop_init(pop)
pop_init(pop)
pop_init(pop)
pop_init(pop)
pop_init(pop)
print(compte(pop))
# Out:
# 266
# 275
# 275
# 238
# 146
# 712
# 326

# %%
plt.scatter(15,17, c = 'red', alpha = 1, edgecolors = 'black')
plt.scatter(65,27, c = 'red', alpha = 0.3, edgecolors = 'black')
plt.scatter(85,45, c = 'red', alpha = 0.7, edgecolors = 'black')
plt.scatter(28,93, c = 'red', alpha = 0.1 , edgecolors = 'black')

plt.xlim(0,100)
plt.ylim(0,100)
plt.show()
