# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math
# %matplotlib inline
from matplotlib import cm

# %%
def person():
    genre = ['h','f'] ; f=False
    X = random.randint(0,100)
    Y = random.randint(0,100)
    g = genre[math.floor(2*random.random())]
    nb_age = random.random()
    if nb_age<0.16 :
        Age = random.randint(15,29)
    elif nb_age<0.3925 :
        Age = random.randint(30,39)
    elif nb_age<0.635 :
        Age = random.randint(40,49)
    elif nb_age<0.8275 :
        Age = random.randint(50,59)
    else :
        Age = random.randint(60,80)
        
    nb_sp = random.random()
    if nb_sp<0.09 :
        sp = 'chomeur'
    else :
        nb_sp = random.random()
        if Age<18 :
            if nb_sp<0.02 :
                sp = 'agri'
            elif nb_sp<0.06 :
                sp = 'ceo'
            elif nb_sp<0.15 :
                sp = 'cadre'
            elif nb_sp<0.36 :
                sp = 'pro_interm'
            elif nb_sp<0.85 :
                sp = 'employe'
            else : 
                sp = 'ouvrier'
        if g == 'h':
            if Age<30 :
                if nb_sp<0.01 :
                    sp = 'agri'
                elif nb_sp<0.03 :
                    sp = 'ceo'
                elif nb_sp<0.14 :
                    sp = 'cadre'
                elif nb_sp<0.34 :
                    sp = 'pro_interm'
                elif nb_sp<0.51 :
                    sp = 'employe'
                else : 
                    sp = 'ouvrier'
            elif Age<40 :
                if nb_sp<0.04 :
                    sp = 'agri'
                elif nb_sp<0.1 :
                    sp = 'ceo'
                elif nb_sp<0.26 :
                    sp = 'cadre'
                elif nb_sp<0.47 :
                    sp = 'pro_interm'
                elif nb_sp<0.61 :
                    sp = 'employe'
                else : 
                    sp = 'ouvrier'
            elif Age<50 :
                if nb_sp<0.04 :
                    sp = 'agri'
                elif nb_sp<0.12 :
                    sp = 'ceo'
                elif nb_sp<0.27 :
                    sp = 'cadre'
                elif nb_sp<0.49 :
                    sp = 'pro_interm'
                elif nb_sp<0.62 :
                    sp = 'employe'
                else : 
                    sp = 'ouvrier'
            elif Age<60 :
                if nb_sp<0.05 :
                    sp = 'agri'
                elif nb_sp<0.16 :
                    sp = 'ceo'
                elif nb_sp<0.36 :
                    sp = 'cadre'
                elif nb_sp<0.6 :
                    sp = 'pro_interm'
                elif nb_sp<0.69 :
                    sp = 'employe'
                else : 
                    sp = 'ouvrier'
            elif Age<66 :
                if nb_sp<0.1 :
                    sp = 'agri'
                elif nb_sp<0.22 :
                    sp = 'ceo'
                elif nb_sp<0.39 :
                    sp = 'cadre'
                elif nb_sp<0.6 :
                    sp = 'pro_interm'
                elif nb_sp<0.69 :
                    sp = 'employe'
                else : 
                    sp = 'ouvrier'
            else : 
                sp = 'retraite'
        else :
            if Age<30 :
                if nb_sp<0.002 :
                    sp = 'agri'
                elif nb_sp<0.012 :
                    sp = 'ceo'
                elif nb_sp<0.092 :
                    sp = 'cadre'
                elif nb_sp<0.312 :
                    sp = 'pro_interm'
                elif nb_sp<0.832 :
                    sp = 'employe'
                else : 
                    sp = 'ouvrier'
            elif Age<40 :
                if nb_sp<0.01 :
                    sp = 'agri'
                elif nb_sp<0.03 :
                    sp = 'ceo'
                elif nb_sp<0.14 :
                    sp = 'cadre'
                elif nb_sp<0.35 :
                    sp = 'pro_interm'
                elif nb_sp<0.86 :
                    sp = 'employe'
                else : 
                    sp = 'ouvrier'
            elif Age<50 :
                if nb_sp<0.02 :
                    sp = 'agri'
                elif nb_sp<0.06 :
                    sp = 'ceo'
                elif nb_sp<0.15 :
                    sp = 'cadre'
                elif nb_sp<0.36 :
                    sp = 'pro_interm'
                elif nb_sp<0.85 :
                    sp = 'employe'
                else : 
                    sp = 'ouvrier'
            elif Age<60 :
                if nb_sp<0.03 :
                    sp = 'agri'
                elif nb_sp<0.08 :
                    sp = 'ceo'
                elif nb_sp<0.2 :
                    sp = 'cadre'
                elif nb_sp<0.41 :
                    sp = 'pro_interm'
                elif nb_sp<0.84 :
                    sp = 'employe'
                else : 
                    sp = 'ouvrier'
            elif Age<66 :
                if nb_sp<0.1 :
                    sp = 'agri'
                elif nb_sp<0.19 :
                    sp = 'ceo'
                elif nb_sp<0.25 :
                    sp = 'cadre'
                elif nb_sp<0.39 :
                    sp = 'pro_interm'
                elif nb_sp<0.8 :
                    sp = 'employe'
                else : 
                    sp = 'ouvrier'
            else : 
                sp = 'retraite'
    nb_c = random.random()
    if Age<30 :
        if nb_c<0.01 :
            c = 'ill'
        else :
            c = 'healthy'
    elif Age<50 :
        nb_c = random.random()
        if nb_c<0.1 :
            c = 'ill'
        else :
            c = 'healthy'
    elif Age<65 :
        nb_c = random.random()
        if nb_c<0.4 :
            c = 'ill'
        else : 
            c = 'healthy'
    else :
        nb_c = random.random()
        if nb_c<0.7 :
            c = 'ill'
        else : 
            c = 'healthy'
    
    if sp == 'ceo' or sp == 'cadre':
        if c == 'healthy':
            if g == 'h':
                fume = random.random()
                if fume<0.094:
                    f = True
            else :
                fume = random.random()
                if fume<0.074: 
                    f = True
        else :
            if g == 'h':
                fume = random.random()
                if fume<0.05:
                    f = True
            else :
                fume = random.random()
                if fume<0.03:
                    f = True
    elif sp == 'chomeur' and Age<55 :
        if g == 'h':
            n = random.random()
            if n<0.564:
                f=True
        else :
            n = random.random()
            if n<0.454:
                f=True
    elif sp == 'chomeur' and Age>=55 :
        n = random.random()
        if n<0.205:
            f=True
    else :
        if f == False :
            nb_f = random.random()
            if Age<20 :
                l = 0.39 
                if c == 'ill' :
                    l = l/2 
                    if nb_f<l :
                        f = True
                else :
                    l = 1.2*l
                    if nb_f<l :
                        f = True

            elif Age<26 :
                nb_f = random.random()
                l = 0.45
                if c == 'ill' :
                    l = l/3
                    if nb_f<l :
                        f = True
                else :
                    l = 1.2*l
                    if nb_f<l :
                        f = True     
            elif Age<50 :
                nb_f = random.random()
                l = 0.27
                if c == 'ill' :
                    l = l/3 
                    if nb_f<l :
                        f = True
                else :
                    l = 1.1*l
                    if nb_f<l :
                        f = True
            elif Age<60 :
                if g == 'h':
                    nb_f = random.random()
                    l = 0.17
                    if c == 'ill' :
                        l = l/7
                        if nb_f<l :
                            f = True
                    else :
                        l = 1.2*l
                        if nb_f<l :
                            f = True
                else :
                    nb_f = random.random()
                    l = 0.08
                    if c == 'ill' :
                        l = l/8 
                        if nb_f<l :
                            f = True
                    else :
                        l = 1.3*l
                        if nb_f<l :
                            f = True
            else :
                if g == 'h':
                    nb_f = random.random()
                    l = 0.12
                    if c == 'ill' :
                        l = l/7
                        if nb_f<l :
                            f = True
                    else :
                        l = 2*l
                        if nb_f<l :
                            f = True
                else :
                    nb_f = random.random()
                    l = 0.05
                    if c == 'ill' :
                        l = l/10 
                        if nb_f<l :
                            f = True
                    else :
                        l = 1.2*l
                        if nb_f<l :
                              f = True       
    if f :
        color = 'red'
    else : 
        color = 'white'
    arret_def = random.randint(3,5) ; nb_pub = 0 ; nb_lutte = 0 
           
    return [X, Y, color, Age, g, sp, c, arret_def, nb_pub, nb_lutte, f]

# %%
def create_pop(n):
    pop = []
    for i in range (n) :
        pop.append(person())
    return pop

pop = create_pop(10)

# %%
def interaction_proche(pop):
    proche = []
    x_val = [x[0] for x in pop]
    y_val = [x[1] for x in pop]
    for i in range(len(pop)):
        proche.append([])
    for i in range (len(pop)):
        dist = [np.sqrt((x_val[i] - x[0])**2 + (y_val[i] - x[1])**2) for x in pop]
        pgeo_i = [dist.index(j) for j in dist if j < 200]
        psoc_i = []
        for j in range(len(pgeo_i)):
            if i != j and j not in proche[i]:
                pi = pop[i]
                pj = pop[j]
                inter = random.random()
                if pi[5] == pj[5]: #même catégorie socio-professionnelle
                    if pi[3]-pj[3]<10:
                        if inter < 0.001:
                            proche[i].append(j)
                            proche[j].append(i)
                    elif pi[3]-pj[3]<20:
                        if inter < 0.0012:
                            proche[i].append(j)
                            proche[j].append(i)
                    else:
                        if inter < 0.0001:
                            proche[i].append(j)
                            proche[j].append(i)
                        
                else:
                    if pi[3]-pj[3]<10:
                        if inter < 0.0003:
                            proche[i].append(j)
                            proche[j].append(i)
                    elif pi[3]-pj[3]<20:
                        if inter < 0.00008:
                            proche[i].append(j)
                            proche[j].append(i)
                    else:
                        if inter < 0.00001:
                            proche[i].append(j)
                            proche[j].append(i)


    i=0
    while i<len(proche):
        for j in proche[i]:
            change=[]
            if pop[j][-1]:
                for a in proche[i]:
                    if pop[a][-1]==False :
                        change.append(a)
            fume = random.random()
            if fume<0.05 and len(change)>1:
                n=change[random.randint(0,len(change)-1)]
                if pop[n][-4]!=0:
                    pop[n][-1]=True
        i=i+1

    return pop

pop = create_pop(100)
print(compte(pop))
interaction_proche(pop)
compte(pop)
# Out:
# 27
# 27

# %%
def debute_age_sponta(pop): 
    for i in range(len(pop)) :
        if pop[i][-4]>0:
            if 15<=pop[i][3]<=30 :
                if pop[i][-1]==False :
                    fume = random.random()
                    if fume<0.4 :
                        pop[i][-1]=True
                        pop[i][2]='red'
                        ar = random.random() 
                        if ar<0.65:
                            pop[i][-1]=False
                            pop[i][2]='white'           
            else :
                if pop[4]=='h':
                    if pop[i][-1]==False and pop[i][6]=='healthy' :
                        fume = random.random()
                        if fume<0.2 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                            ar = random.random()
                            if ar<0.55:
                                pop[i][-1]=False
                                pop[i][2]='white'
                else :
                    if pop[i][-1]==False and pop[i][6]=='healthy' :
                        fume = random.random()
                        if fume<0.15 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                            ar = random.random()
                            if ar<0.5:
                                pop[i][-1]=False
                                pop[i][2]='white'
                            
pop = [[13, 12, 'white', 35, 'h', 'ouvrier', 'healthy', 0, 0, 0, False], \
    [14, 12, 'white', 20, 'f', 'employe', 'healthy', 0, 0, 0, False], \
    [14, 11, 'red', 25, 'h', 'chomeur', 'healthy', 0, 0, 0, True], \
    [45, 60, 'white', 76, 'h', 'retraite', 'healthy', 0, 0, 0, False], [56, 67, 'red', 72, 'h', 'retraite', 'healthy', 0, 0, 0, True]]

debute_age_sponta(pop)

print(pop)
# Out:
# [[13, 12, 'white', 35, 'h', 'ouvrier', 'healthy', 0, 0, 0, False], [14, 12, 'white', 20, 'f', 'employe', 'healthy', 0, 0, 0, False], [14, 11, 'red', 25, 'h', 'chomeur', 'healthy', 0, 0, 0, True], [45, 60, 'white', 76, 'h', 'retraite', 'healthy', 0, 0, 0, False], [56, 67, 'red', 72, 'h', 'retraite', 'healthy', 0, 0, 0, True]]

# %%
def arret_reprise_sponta(pop): #chaque année
    for i in range(len(pop)) :
        if pop[i][-1]:
            if pop[i][-4]>0:
                if pop[i][6]=='ill' :
                    n = random.random()
                    if n<0.8 :
                        pop[i][-4]=pop[i][-4]-1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        reprise = random.random()
                        if reprise<0.2 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                else :
                    if pop[i][5]=='ceo' or pop[i][5]=='cadre' or pop[i][3]>50 :
                        n = random.random()
                        if n<0.25 : #arrêt d'un an au moins
                            pop[i][-4]=pop[i][-4]-1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.55 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                    else :
                        n = random.random()
                        if n<0.1 :
                            pop[i][-4]=pop[i][-4]+1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.7 :
                                pop[i][-1]=True
                                pop[i][2]='red'

# %%
def diffu_lutte(pop):
    for i in range(len(pop)) :
        if pop[i][3]<41 :
            l = 4
        else :
            l = 6
        vu = random.random()
        if pop[i][-2]<l:
            if vu<0.25:
                pop[i][-2]=pop[i][-2]+1
        if pop[i][-4]>0 :
            if pop[i][-1]:
                n = random.random()
                if pop[i][-2]>=l:
                    if n<0.85 :
                        pop[i][-4]=pop[i][-4]-1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        if pop[i][-4]>0 :#parmi ceux qui ont vu plusieurs fois la campagne
                            if n<0.1 : #si elle a échoué
                                pop[i][-1]=True
                                pop[i][2]='red'
                elif pop[i][-2]>=l/2:
                    if n<0.5 :
                        pop[i][-4]=pop[i][-4]-1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        if pop[i][-4]>0 :#parmi ceux qui ont vu plusieurs fois la campagne
                            if n<0.4 : #si elle a échoué
                                pop[i][-1]=True
                                pop[i][2]='red'
                else :
                    if n<0.2 :
                        pop[i][-4]=pop[i][-4]-1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        pop[i][-5]=1
                        if pop[i][-4]>0 :
                            n = random.random()
                            if n<0.65 :
                                pop[i][-1]=True
                                pop[i][2]='red'

# %%
def diffu_pub(pop):
    radio = random.random()
    tv = random.random()
    reseau = random.random() 
    n = random.random()
    for i in range(len(pop)) :
        if pop[i][3]<41 :
            l = 8
        else :
            l = 12
        if pop[i][-2]<l:
            if radio<0.15:
                pop[i][-3]=pop[i][-3]+1
            if tv<0.12:
                pop[i][-3]=pop[i][-3]+1
            if pop[i][3]<60:
                if reseau<0.6:
                    pop[i][-3]=pop[i][-3]+1
            else:
                if reseau<0.2:
                    pop[i][-3]=pop[i][-3]+1
        if pop[i][-4]>0 :
            if pop[i][-1]==False:
                if pop[i][-3]>=l:
                    if n<0.25 :
                        pop[i][-1]=True
                        pop[i][2]='red'
                        if n<0.1 : #dès qu'elle arrête de diffuser
                                pop[i][-1]=False
                                pop[i][2]='white'
                                pop[i][-4]=pop[i][-4]-1
                if pop[i][-3]>=l/2:
                    if n<0.011 :
                        pop[i][-1]=True
                        pop[i][2]='red'
                        n=random.random()
                        if n<0.25 : #dès qu'elle arrête de diffuser
                                pop[i][-1]=False
                                pop[i][2]='white'
                                pop[i][-4]=pop[i][-4]-1
                else :
                    if n<0.005 :
                        pop[i][-1]=True
                        pop[i][2]='red'
                        n=random.random()
                        if n<0.6 : #dès qu'elle arrête de diffuser
                                pop[i][-1]=False
                                pop[i][2]='white'
                                pop[i][-4]=pop[i][-4]-1

# %%
def compte(pop):
    r = 0
    for i in range(len(pop)):
        if pop[i][-1]:
            r = r+1
    return r

# %%
def pop_init(pop):
    interaction_proche(pop)
    debute_age_sponta(pop)
    arret_reprise_sponta(pop)
    diffu_lutte(pop)
    diffu_pub(pop)
    
    x_val = [x[0] for x in pop]
    y_val = [x[1] for x in pop]
    color = [x[2] for x in pop]

    d=[random.randint(1,100) for i in range(0,len(pop))]
    for i in range(len(d)):
        if d[i]<36:
            plt.scatter(x_val,y_val,c=color,alpha=random.uniform(0.8,1),edgecolors = 'black')
        elif d[i]<56:
            plt.scatter(x_val,y_val,c=color,alpha=random.uniform(0.5,0.6),edgecolors = 'black')
        else :
            plt.scatter(x_val,y_val,c=color,alpha=random.uniform(0.2,0.3),edgecolors = 'black')
    
    plt.scatter(random.randint(10,90),random.randint(10,90),s=14**2,c = 'blue', marker = 'X',edgecolors = 'black')
    plt.scatter(random.randint(10,90),random.randint(10,90),s=14**2,c = 'blue', marker = 'D',edgecolors = 'black')
    plt.scatter(random.randint(10,90),random.randint(10,90),s=14**2,c = 'blue', marker = 'H',edgecolors = 'black')
    plt.scatter(random.randint(10,90),random.randint(10,90),s=20**2,c = 'yellow', marker = '*',edgecolors = 'black')
    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)

    plt.xlim(0,100)
    plt.ylim(0,100)
    plt.show()
    
pop = create_pop(1000)
print(compte(pop))

pop_init(pop)
print(compte(pop))
# Out:
# 228
# 230

# %%
def affiche(pop, date = 0):
    
    fig = plt.figure(figsize = (6,6))
    
    x_val = [x[0] for x in pop]
    y_val = [x[1] for x in pop]
    color = [x[2] for x in pop]
            
    plt.scatter(x_val,y_val, c = color, edgecolors = 'black')
    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    
    year = 2022 + date
    plt.title(str(year))

    plt.xlim(0,100)
    plt.ylim(0,100)
    plt.show()

# %%
def move_year(pop):
    for i in range(len(pop)):
        pop[i][0] += random.randint(-5,5) 
        if pop[i][0]<0:
            pop[i][0] = 0
        elif pop[i][0]>100:
            pop[i][0] = 100
            
        pop[i][1] += random.randint(-5,5)
        if pop[i][1]<0:
            pop[i][1] = 0
        elif pop[i][1]>100:
            pop[i][1] = 100
    interaction_proche(pop)        
    debute_age_sponta(pop)
    arret_reprise_sponta(pop)
    diffu_pub(pop)
    
        
    return pop

# %%
def simulation(pop,year):
    
    date = 0
    nbf = [sum(bool(x[10]) for x in pop)/len(pop)*100]

    for i in range(1,year+1):
        pop = move_year(pop)
        date += 1
        nbf.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        color = [x[2] for x in pop]
    
    affiche(pop,date)

    plt.plot(nbf)
    axes = plt.gca()
    axes.set_xlabel('Date')
    axes.set_ylabel('% de fumeur')
    plt.ylim(0,100)
    plt.xlim(0,year)
    plt.show()

# %%
pop=create_pop(1000)
simulation(pop,10)
