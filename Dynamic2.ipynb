# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math
# %matplotlib inline

# %%
genre = ['h','f']

def person():
    X = random.randint(0,100)
    Y = random.randint(0,100)
    g = genre[math.floor(random.random())]
    nb_age = random.random()
    if nb_age<0.16 :
        Age = random.randint(15,29)
    elif nb_age<0.3925 :
        Age = random.randint(30,39)
    elif nb_age<0.635 :
        Age = random.randint(40,49)
    elif nb_age<0.8275 :
        Age = random.randint(50,59)
    else :
        Age = random.randint(60,80)
    nb_sp = random.random() ; sp = 'N'
    if Age<18 :
        sp = 'ado'
    else :
        if nb_sp<0.09 :
            sp = 'chomeur'
        if sp == 'N' :
            nb_sp = random.random()
            if 18<=Age<=24 :
                if nb_sp<0.5 :
                    sp = 'etu'
            elif Age<=29 :
                if 0.5<=nb_sp<0.56 :
                    sp = 'etu'
            if sp == 'N' :
                if g == 'h' :
                    if Age<30 :
                        if nb_sp<0.01 :
                            sp = 'agri'
                        elif nb_sp<0.03 :
                            sp = 'ceo'
                        elif nb_sp<0.14 :
                            sp = 'cadre'
                        elif nb_sp<0.34 :
                            sp = 'pro_interm'
                        elif nb_sp<0.51 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<40 :
                        if nb_sp<0.04 :
                            sp = 'agri'
                        elif nb_sp<0.1 :
                            sp = 'ceo'
                        elif nb_sp<0.26 :
                            sp = 'cadre'
                        elif nb_sp<0.47 :
                            sp = 'pro_interm'
                        elif nb_sp<0.61 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<50 :
                        if nb_sp<0.04 :
                            sp = 'agri'
                        elif nb_sp<0.12 :
                            sp = 'ceo'
                        elif nb_sp<0.27 :
                            sp = 'cadre'
                        elif nb_sp<0.49 :
                            sp = 'pro_interm'
                        elif nb_sp<0.62 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<60 :
                        if nb_sp<0.05 :
                            sp = 'agri'
                        elif nb_sp<0.16 :
                            sp = 'ceo'
                        elif nb_sp<0.36 :
                            sp = 'cadre'
                        elif nb_sp<0.6 :
                            sp = 'pro_interm'
                        elif nb_sp<0.69 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<66 :
                        if nb_sp<0.1 :
                            sp = 'agri'
                        elif nb_sp<0.22 :
                            sp = 'ceo'
                        elif nb_sp<0.39 :
                            sp = 'cadre'
                        elif nb_sp<0.6 :
                            sp = 'pro_interm'
                        elif nb_sp<0.69 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    else : 
                        sp = 'retraite'
                else :
                    if Age<30 :
                        if nb_sp<0.002 :
                            sp = 'agri'
                        elif nb_sp<0.012 :
                            sp = 'ceo'
                        elif nb_sp<0.092 :
                            sp = 'cadre'
                        elif nb_sp<0.312 :
                            sp = 'pro_interm'
                        elif nb_sp<0.832 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<40 :
                        if nb_sp<0.01 :
                            sp = 'agri'
                        elif nb_sp<0.03 :
                            sp = 'ceo'
                        elif nb_sp<0.14 :
                            sp = 'cadre'
                        elif nb_sp<0.35 :
                            sp = 'pro_interm'
                        elif nb_sp<0.86 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<50 :
                        if nb_sp<0.02 :
                            sp = 'agri'
                        elif nb_sp<0.06 :
                            sp = 'ceo'
                        elif nb_sp<0.15 :
                            sp = 'cadre'
                        elif nb_sp<0.36 :
                            sp = 'pro_interm'
                        elif nb_sp<0.85 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<60 :
                        if nb_sp<0.03 :
                            sp = 'agri'
                        elif nb_sp<0.08 :
                            sp = 'ceo'
                        elif nb_sp<0.2 :
                            sp = 'cadre'
                        elif nb_sp<0.41 :
                            sp = 'pro_interm'
                        elif nb_sp<0.84 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<66 :
                        if nb_sp<0.1 :
                            sp = 'agri'
                        elif nb_sp<0.19 :
                            sp = 'ceo'
                        elif nb_sp<0.25 :
                            sp = 'cadre'
                        elif nb_sp<0.39 :
                            sp = 'pro_interm'
                        elif nb_sp<0.8 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    else : 
                        sp = 'retraite'
    nb_c = random.random()
    if Age<30 :
        if nb_c<0.01 :
            c = 'ill'
        else :
            c = 'healthy'
    elif Age<50 :
        nb_c = random.random()
        if nb_c<0.1 :
            c = 'ill'
        else :
            c = 'healthy'
    elif Age<65 :
        nb_c = random.random()
        if nb_c<0.4 :
            c = 'ill'
        else : 
            c = 'healthy'
    else :
        nb_c = random.random()
        if nb_c<0.7 :
            c = 'ill'
        else : 
            c = 'healthy'
    nb_f = random.random()
    if Age<20 :
        l = 0.39 
        if c == 'ill' :
            l = l/2 
            if nb_f<l :
                f = True
            else :
                f = False
        else :
            l = 1.2*l
            if nb_f<l :
                f = True
            else :
                f = False
    elif Age<26 :
        nb_f = random.random()
        l = 0.45
        if c == 'ill' :
            l = l/3
            if nb_f<l :
                f = True
            else :
                f = False
        else :
            l = 1.2*l
            if nb_f<l :
                f = True
            else :
                f = False
        
    elif Age<50 :
        nb_f = random.random()
        l = 0.27
        if c == 'ill' :
            l = l/3 
            if nb_f<l :
                f = True
            else :
                f = False
        else :
            l = 1.1*l
            if nb_f<l :
                f = True
            else :
                f = False
    elif Age<60 :
        if g == 'h':
            nb_f = random.random()
            l = 0.17
            if c == 'ill' :
                l = l/7
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 1.2*l
                if nb_f<l :
                    f = True
                else :
                    f = False
        else :
            nb_f = random.random()
            l = 0.08
            if c == 'ill' :
                l = l/8 
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 1.3*l
                if nb_f<l :
                    f = True
                else :
                    f = False
    else :
        if g == 'h':
            nb_f = random.random()
            l = 0.12
            if c == 'ill' :
                l = l/7
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 2*l
                if nb_f<l :
                    f = True
                else :
                    f = False
        else :
            nb_f = random.random()
            l = 0.05
            if c == 'ill' :
                l = l/10 
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 1.2*l
                if nb_f<l :
                    f = True
                else :
                    f = False
    if f :
        color = 'red'
    else : 
        color = 'white'
            
    return [X,Y,color,Age,g,sp,c,f]

# %%
def create_pop(n):
    pop = []
    for i in range (n) :
        pop.append(person())
    return pop

create_pop(10)
# Out:
# [[100, 43, 'red', 59, 'h', 'cadre', 'ill', True],
#  [57, 100, 'white', 42, 'h', 'chomeur', 'healthy', False],
#  [20, 26, 'red', 37, 'h', 'chomeur', 'healthy', True],
#  [44, 8, 'white', 30, 'h', 'ouvrier', 'healthy', False],
#  [54, 57, 'red', 21, 'h', 'etu', 'healthy', True],
#  [22, 82, 'white', 50, 'h', 'ceo', 'healthy', False],
#  [24, 30, 'white', 46, 'h', 'cadre', 'healthy', False],
#  [53, 7, 'white', 63, 'h', 'ouvrier', 'ill', False],
#  [4, 56, 'white', 49, 'h', 'employe', 'healthy', False],
#  [51, 75, 'white', 28, 'h', 'ouvrier', 'healthy', False]]

# %%
def diffuseur_pub(pourc_pop,pourc_non_fumeur,taux):
    val_alea = random.randint(0,pourc_fumeur)
    
    pourc_non_fumeur_final = pourc_non_fumeur + (val_alea*taux)
    return pourc_non_fumeur_final



def campagne_prév(pourc_pop,pourc_fumeur,taux):
    val_alea = random.randint(0,pourc_fumeur)
    
    pourc_fumeur_final = pourc_fumeur + (val_alea*taux)
    return pourc_fumeur_final
    
    
#1ere fois *0.1
#2eme fois *0.3
#3eme fois *0.7

# %%
val_alea = random.randint(0,100)

#diffuseur de pub
    for i in range(pop) :  
        for pers in range(i):
            if pers[4] < 60:     #pers[4] = âge
                pers[-3] = pers[-3]*..     #pers[-3] = nb vue Pub
                
                
            if pers[4] >= 60:
                pers[-3] = pers[-3]*

                
#campagnes de prévention
    for i in range(pop) :  
        for pers in range(i):
            if pers[4] < 60:     #pers[4] = âge
                pers[-2] = pers[-2]*     #pers[-2] = nb de vues Anti
                
                
            if pers[4] >= 60:
                pers[-2] = pers[-2]*

# %%
#paramètre: nombre de visualisation de pub et anti

    for i in range(pop) :  
        for pers in range(i):
            if pers[-3] == 4:     #[X,Y,color,Age,g,sp,c,P,A,f] avec P : nb vue Pub et A : nb de vues Anti
                pers[-1] = True
            if pers[-2] == 4:
                pers[-1] = False

# %%
def pop_init(nb):
    pop = create_pop(nb)
    pop = np.array(pop)
            
    plt.scatter(pop[:,0],pop[:,1], c = pop[:,2], edgecolors = 'black')
    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    plt.show()
    
    return pop

pop = pop_init(1000)
