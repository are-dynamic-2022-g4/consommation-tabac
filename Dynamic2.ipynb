# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import random
import math
# %matplotlib inline

# %%
def person():
    genre = ['h','f']
    X = random.randint(0,100)
    Y = random.randint(0,100)
    g = genre[math.floor(2*random.random())]
    nb_age = random.random()
    if nb_age<0.16 :
        Age = random.randint(15,29)
    elif nb_age<0.3925 :
        Age = random.randint(30,39)
    elif nb_age<0.635 :
        Age = random.randint(40,49)
    elif nb_age<0.8275 :
        Age = random.randint(50,59)
    else :
        Age = random.randint(60,80)
    nb_sp = random.random() ; sp = 'N'
    if Age<18 :
        sp = 'ado'
    else :
        if nb_sp<0.09 :
            sp = 'chomeur'
        if sp == 'N' :
            nb_sp = random.random()
            if 18<=Age<=24 :
                if nb_sp<0.5 :
                    sp = 'etu'
            elif Age<=29 :
                if 0.5<=nb_sp<0.56 :
                    sp = 'etu'
            if sp == 'N' :
                if g == 'h' :
                    if Age<30 :
                        if nb_sp<0.01 :
                            sp = 'agri'
                        elif nb_sp<0.03 :
                            sp = 'ceo'
                        elif nb_sp<0.14 :
                            sp = 'cadre'
                        elif nb_sp<0.34 :
                            sp = 'pro_interm'
                        elif nb_sp<0.51 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<40 :
                        if nb_sp<0.04 :
                            sp = 'agri'
                        elif nb_sp<0.1 :
                            sp = 'ceo'
                        elif nb_sp<0.26 :
                            sp = 'cadre'
                        elif nb_sp<0.47 :
                            sp = 'pro_interm'
                        elif nb_sp<0.61 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<50 :
                        if nb_sp<0.04 :
                            sp = 'agri'
                        elif nb_sp<0.12 :
                            sp = 'ceo'
                        elif nb_sp<0.27 :
                            sp = 'cadre'
                        elif nb_sp<0.49 :
                            sp = 'pro_interm'
                        elif nb_sp<0.62 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<60 :
                        if nb_sp<0.05 :
                            sp = 'agri'
                        elif nb_sp<0.16 :
                            sp = 'ceo'
                        elif nb_sp<0.36 :
                            sp = 'cadre'
                        elif nb_sp<0.6 :
                            sp = 'pro_interm'
                        elif nb_sp<0.69 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<66 :
                        if nb_sp<0.1 :
                            sp = 'agri'
                        elif nb_sp<0.22 :
                            sp = 'ceo'
                        elif nb_sp<0.39 :
                            sp = 'cadre'
                        elif nb_sp<0.6 :
                            sp = 'pro_interm'
                        elif nb_sp<0.69 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    else : 
                        sp = 'retraite'
                else :
                    if Age<30 :
                        if nb_sp<0.002 :
                            sp = 'agri'
                        elif nb_sp<0.012 :
                            sp = 'ceo'
                        elif nb_sp<0.092 :
                            sp = 'cadre'
                        elif nb_sp<0.312 :
                            sp = 'pro_interm'
                        elif nb_sp<0.832 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<40 :
                        if nb_sp<0.01 :
                            sp = 'agri'
                        elif nb_sp<0.03 :
                            sp = 'ceo'
                        elif nb_sp<0.14 :
                            sp = 'cadre'
                        elif nb_sp<0.35 :
                            sp = 'pro_interm'
                        elif nb_sp<0.86 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<50 :
                        if nb_sp<0.02 :
                            sp = 'agri'
                        elif nb_sp<0.06 :
                            sp = 'ceo'
                        elif nb_sp<0.15 :
                            sp = 'cadre'
                        elif nb_sp<0.36 :
                            sp = 'pro_interm'
                        elif nb_sp<0.85 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<60 :
                        if nb_sp<0.03 :
                            sp = 'agri'
                        elif nb_sp<0.08 :
                            sp = 'ceo'
                        elif nb_sp<0.2 :
                            sp = 'cadre'
                        elif nb_sp<0.41 :
                            sp = 'pro_interm'
                        elif nb_sp<0.84 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<66 :
                        if nb_sp<0.1 :
                            sp = 'agri'
                        elif nb_sp<0.19 :
                            sp = 'ceo'
                        elif nb_sp<0.25 :
                            sp = 'cadre'
                        elif nb_sp<0.39 :
                            sp = 'pro_interm'
                        elif nb_sp<0.8 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    else : 
                        sp = 'retraite'
    nb_c = random.random()
    if Age<30 :
        if nb_c<0.01 :
            c = 'ill'
        else :
            c = 'healthy'
    elif Age<50 :
        nb_c = random.random()
        if nb_c<0.1 :
            c = 'ill'
        else :
            c = 'healthy'
    elif Age<65 :
        nb_c = random.random()
        if nb_c<0.4 :
            c = 'ill'
        else : 
            c = 'healthy'
    else :
        nb_c = random.random()
        if nb_c<0.7 :
            c = 'ill'
        else : 
            c = 'healthy'
    nb_f = random.random()
    if Age<20 :
        l = 0.39 
        if c == 'ill' :
            l = l/2 
            if nb_f<l :
                f = True
            else :
                f = False
        else :
            l = 1.2*l
            if nb_f<l :
                f = True
            else :
                f = False
    elif Age<26 :
        nb_f = random.random()
        l = 0.45
        if c == 'ill' :
            l = l/3
            if nb_f<l :
                f = True
            else :
                f = False
        else :
            l = 1.2*l
            if nb_f<l :
                f = True
            else :
                f = False
        
    elif Age<50 :
        nb_f = random.random()
        l = 0.27
        if c == 'ill' :
            l = l/3 
            if nb_f<l :
                f = True
            else :
                f = False
        else :
            l = 1.1*l
            if nb_f<l :
                f = True
            else :
                f = False
    elif Age<60 :
        if g == 'h':
            nb_f = random.random()
            l = 0.17
            if c == 'ill' :
                l = l/7
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 1.2*l
                if nb_f<l :
                    f = True
                else :
                    f = False
        else :
            nb_f = random.random()
            l = 0.08
            if c == 'ill' :
                l = l/8 
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 1.3*l
                if nb_f<l :
                    f = True
                else :
                    f = False
    else :
        if g == 'h':
            nb_f = random.random()
            l = 0.12
            if c == 'ill' :
                l = l/7
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 2*l
                if nb_f<l :
                    f = True
                else :
                    f = False
        else :
            nb_f = random.random()
            l = 0.05
            if c == 'ill' :
                l = l/10 
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 1.2*l
                if nb_f<l :
                    f = True
                else :
                    f = False
    if sp == 'ceo' or sp == 'cadre':
        if f == False :
            if c == 'healthy':
                if g == 'h':
                    fume = random.random()
                    if fume<0.094:
                        f = True
                else :
                    fume = random.random()
                    if fume<0.074:
                        f = True
            else :
                if g == 'h':
                    fume = random.random()
                    if fume<0.05:
                        f = True
                else :
                    fume = random.random()
                    if fume<0.03:
                        f = True
    if f :
        color = 'red'
    else : 
        color = 'white'
    nb_essai_arret = 0 ; nb_pub = 0 ; nb_lutte = 0   
           
    return [X,Y,color,Age,g,sp,c,nb_essai_arret,nb_pub,nb_lutte,f]

# %%
def create_pop(n):
    pop = []
    for i in range (n) :
        pop.append(person())
    return pop

create_pop(10)
# Out:
# [[70, 5, 'white', 32, 'h', 'employe', 'healthy', 0, 0, 0, False],
#  [22, 41, 'red', 49, 'h', 'ouvrier', 'healthy', 0, 0, 0, True],
#  [51, 22, 'red', 54, 'h', 'chomeur', 'healthy', 0, 0, 0, True],
#  [68, 64, 'white', 32, 'f', 'employe', 'healthy', 0, 0, 0, False],
#  [5, 46, 'red', 45, 'f', 'employe', 'healthy', 0, 0, 0, True],
#  [87, 89, 'white', 40, 'f', 'chomeur', 'healthy', 0, 0, 0, False],
#  [60, 11, 'red', 22, 'h', 'etu', 'healthy', 0, 0, 0, True],
#  [36, 7, 'white', 48, 'f', 'employe', 'healthy', 0, 0, 0, False],
#  [15, 93, 'white', 45, 'h', 'pro_interm', 'healthy', 0, 0, 0, False],
#  [14, 51, 'white', 71, 'h', 'retraite', 'ill', 0, 0, 0, False]]

# %%
def proche(pop):
    proche = []
    for i in range(len(pop)):
        proche.append([])
    for i in range (len(pop)):
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        dist = [np.sqrt((x_val[i] - x[0])**2 + (y_val[i] - x[1])**2) for x in pop]
        pgeo_i = [dist.index(j) for j in dist if j < 20]
        psoc_i = []
        for j in range(len(pgeo_i)):
            if i != j and j not in proche[i]:
                pi = pop[i]
                pj = pop[j]
                inter = random.random()
                if pi[5] == pj[5]:
                    if pi[3]-pj[3]<5:
                        if inter < 0.9:
                            proche[i].append(j)
                            proche[j].append(i)
                    elif pi[3]-pj[3]<15:
                        if inter < 0.5:
                            proche[i].append(j)
                            proche[j].append(i)
                    else:
                        if inter < 0.2:
                            proche[i].append(j)
                            proche[j].append(i)
                        
                else:
                    if pi[3]-pj[3]<5:
                        if inter < 0.3:
                            proche[i].append(j)
                            proche[j].append(i)
                    elif pi[3]-pj[3]<15:
                        if inter < 0.1:
                            proche[i].append(j)
                            proche[j].append(i)
                    else:
                        if inter < 0.03:
                            proche[i].append(j)
                            proche[j].append(i)
    return proche

#pop = [[13, 12, 'white', 35, 'h', 'ouvrier', 'healthy', False], [14, 12, 'white', 20, 'f', 'employe', 'healthy', False], \[14, 11, 'red', 25, 'h', 'chomeur', 'healthy', True], [45, 60, 'white', 76, 'h', 'retraite', 'healthy', False], [56, 67, 'red', 72, 'h', 'retraite', 'healthy', True]]
 
pop = pop_init(10)

print(pop)
print("\n")  
print(proche(pop))
    


#i=0
#tmp=[]
#while i<len(proche(pop)) :
#    if len(proche(pop)[i])>1 :
#        if i not in tmp :
#            for b in range(1,len(proche(pop)[i])) :
#                tmp.append(b)
#            for j in proche(pop)[i]:
#                change=[]
#                if pop[j][-1]:
#                    for a in proche(pop)[i]:
#                        if pop[a][-1]==False :
#                           change.append(a)
#            fume = random.random()
#            if fume<0.3 :
#                pop[math.floor(len(change)*random.random())][-1]=True
#    i=i+1
#
#print("\n")                
#print(pop)
# Out:
# [[45, 52, 'white', 31, 'f', 'pro_interm', 'healthy', 0, 0, 0, False], [3, 4, 'white', 70, 'f', 'retraite', 'ill', 0, 0, 0, False], [87, 3, 'white', 36, 'f', 'ouvrier', 'healthy', 0, 0, 0, False], [50, 3, 'white', 41, 'f', 'employe', 'ill', 0, 0, 0, False], [9, 40, 'white', 31, 'h', 'ouvrier', 'healthy', 0, 0, 0, False], [61, 48, 'white', 80, 'h', 'retraite', 'ill', 0, 0, 0, False], [75, 81, 'white', 31, 'f', 'employe', 'healthy', 0, 0, 0, False], [5, 100, 'red', 51, 'h', 'cadre', 'healthy', 0, 0, 0, True], [19, 49, 'white', 16, 'f', 'ado', 'healthy', 0, 0, 0, False], [83, 23, 'red', 53, 'h', 'ouvrier', 'healthy', 0, 0, 0, True]]
#
#
# [[], [4, 5, 8], [], [], [1], [1], [], [], [1], []]

# %%
def debute_age_sponta(pop):  #chaque année
    for i in range(len(pop)) :
        if pop[i][-4]<4:
            if 15<=pop[i][3]<=30 :
                if pop[i][-1]==False :
                    fume = random.random()
                    if fume<0.4 :
                        pop[i][-1]=True
                        pop[i][2]='red'
                        ar = random.random()
                        if ar<0.65:
                            pop[i][-1]=False
                            pop[i][2]='white'
                    
                    
            else :
                if pop[4]=='h':
                    if pop[i][-1]==False and pop[i][6]=='healthy' :
                        fume = random.random()
                        if fume<0.2 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                            ar = random.random()
                            if ar<0.55:
                                pop[i][-1]=False
                                pop[i][2]='white'
                else :
                    if pop[i][-1]==False and pop[i][6]=='healthy' :
                        fume = random.random()
                        if fume<0.15 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                            ar = random.random()
                            if ar<0.5:
                                pop[i][-1]=False
                                pop[i][2]='white'
                            
pop = [[13, 12, 'white', 35, 'h', 'ouvrier', 'healthy', 0, 0, 0, False], \
    [14, 12, 'white', 20, 'f', 'employe', 'healthy', 0, 0, 0, False], \
    [14, 11, 'red', 25, 'h', 'chomeur', 'healthy', 0, 0, 0, True], \
    [45, 60, 'white', 76, 'h', 'retraite', 'healthy', 0, 0, 0, False], [56, 67, 'red', 72, 'h', 'retraite', 'healthy', 0, 0, 0, True]]

# %%
def arret_reprise_sponta(pop): #chaque année
    for i in range(len(pop)) :
        if pop[i][-1]:
            if pop[i][-4]<4:
                if pop[i][6]=='ill' :
                    n = random.random()
                    if n<0.5 : #arrêt d'un an au moins, on peut considérer 
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        reprise = random.random()
                        if reprise<0.45 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                        else :
                            pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre 
                else :
                    if pop[i][5]=='ceo' or pop[i][5]=='cadre' or pop[i][3]>50 :
                        n = random.random()
                        if n<0.1 : #arrêt d'un an au moins, on peut considérer 
                            pop[i][-4]=pop[i][-4]+1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.6 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                            else :
                                pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre
                    else :
                        n = random.random()
                        if n<0.045 : #arrêt d'un an au moins, on peut considérer 
                            pop[i][-4]=pop[i][-4]+1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.7 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                            else :
                                pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre

                    
        
pop = create_pop(20)
print(pop)
arret_reprise_sponta(pop)
print(pop)
# Out:
# [[97, 30, 'red', 49, 'f', 'cadre', 'healthy', 0, 0, 0, True], [72, 24, 'white', 65, 'h', 'cadre', 'ill', 0, 0, 0, False], [6, 6, 'white', 36, 'f', 'employe', 'healthy', 0, 0, 0, False], [53, 48, 'red', 37, 'h', 'pro_interm', 'healthy', 0, 0, 0, True], [55, 55, 'white', 26, 'f', 'cadre', 'healthy', 0, 0, 0, False], [67, 12, 'white', 39, 'h', 'ouvrier', 'healthy', 0, 0, 0, False], [87, 94, 'white', 17, 'f', 'ado', 'healthy', 0, 0, 0, False], [22, 35, 'white', 36, 'f', 'pro_interm', 'healthy', 0, 0, 0, False], [82, 98, 'red', 48, 'h', 'pro_interm', 'ill', 0, 0, 0, True], [41, 54, 'white', 17, 'h', 'ado', 'healthy', 0, 0, 0, False], [32, 90, 'white', 48, 'h', 'cadre', 'healthy', 0, 0, 0, False], [12, 42, 'white', 37, 'f', 'pro_interm', 'healthy', 0, 0, 0, False], [46, 7, 'red', 34, 'f', 'cadre', 'healthy', 0, 0, 0, True], [24, 33, 'white', 62, 'f', 'employe', 'ill', 0, 0, 0, False], [69, 76, 'white', 57, 'h', 'pro_interm', 'healthy', 0, 0, 0, False], [34, 54, 'red', 39, 'h', 'ouvrier', '
# ...

# %%
def arret_reprise_sponta(pop): #chaque année
    for i in range(len(pop)) :
        if pop[i][-1]:
            if pop[i][-4]<4:
                if pop[i][6]=='ill' :
                    n = random.random()
                    if n<0.5 : #arrêt d'un an au moins, on peut considérer 
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        reprise = random.random()
                        if reprise<0.45 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                        else :
                            pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre 
                else :
                    if pop[i][5]=='ceo' or pop[i][5]=='cadre' or pop[i][3]>50 :
                        n = random.random()
                        if n<0.1 : #arrêt d'un an au moins, on peut considérer 
                            pop[i][-4]=pop[i][-4]+1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.6 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                            else :
                                pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre
                    else :
                        n = random.random()
                        if n<0.045 : #arrêt d'un an au moins, on peut considérer 
                            pop[i][-4]=pop[i][-4]+1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.7 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                            else :
                                pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre

# %%
def diffu_pub(pop):
    radio = random.random()
    tv = random.random()
    reseau = random.random() 
    n = random.random()
    for i in range(len(pop)) :
        if pop[i][3]<41 :
            l = 6
        else :
            l = 10
        if pop[i][-2]<l:
            if radio<0.3:
                pop[i][-3]=pop[i][-3]+1
            if tv<0.25:
                pop[i][-3]=pop[i][-3]+1
            if pop[i][3]<60:
                if reseau<0.8:
                    pop[i][-3]=pop[i][-3]+1
            else:
                if reseau<0.2:
                    pop[i][-3]=pop[i][-3]+1
        if pop[i][-4]<4 :
            if pop[i][-1]:
                if pop[i][-3]>=l/2:
                    if n<0.11 :
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=True
                        pop[i][2]='red'
                else :
                    if n<0.05 :
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=True
                        pop[i][2]='red'

# %%
def affiche(pop, date = 0):
    
    fig = plt.figure(figsize = (5,5))
    
    x_val = [x[0] for x in pop]
    y_val = [x[1] for x in pop]
    color = [x[2] for x in pop]
            
    plt.scatter(x_val,y_val, c = color, edgecolors = 'black')
    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    
    year = 2022 + date
    plt.title(str(year))

    plt.xlim(0,100)
    plt.ylim(0,100)
    plt.show()

# %%
def pop_init(nb):
    pop = create_pop(nb)
    nbf = [(sum(bool(x[-1]) for x in pop))*100/len(pop)]
    date = 0
    affiche(pop)
    
    return pop

pop = pop_init(1000)

# %%
def year(pop):
    for i in range(len(pop)):
        pop[i][0] += random.randint(-5,5) 
        if pop[i][0]<0:
            pop[i][0] = 0
        elif pop[i][0]>100:
            pop[i][0] = 100
            
        pop[i][1] += random.randint(-5,5)
        if pop[i][1]<0:
            pop[i][1] = 0
        elif pop[i][1]>100:
            pop[i][1] = 100
            
    debute_age_sponta(pop)
    arret_reprise_sponta(pop)
    diffu_pub(pop)
    
        
    return pop

# %%
def simulation(nb_pop, nb_year):
    
    pop = pop_init(nb_pop)
    date = 0
    nbf = [sum(bool(x[10]) for x in pop)/len(pop)*100]


    for i in range(1,nb_year+1):
        pop = year(pop)
        date += 1
        nbf.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        color = [x[2] for x in pop]
    
    affiche(pop,date)

    plt.plot(nbf)
    axes = plt.gca()
    axes.set_xlabel('Date')
    axes.set_ylabel('% de fumeur')
    plt.ylim(0,100)
    plt.xlim(0,nb_year)
    plt.show()

# %%
simulation(1000,20)
