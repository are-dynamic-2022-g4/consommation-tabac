# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import random
import math
# %matplotlib inline

# %%
def person():
    genre = ['h','f']
    X = random.randint(0,100)
    Y = random.randint(0,100)
    g = genre[math.floor(2*random.random())]
    nb_age = random.random()
    if nb_age<0.16 :
        Age = random.randint(15,29)
    elif nb_age<0.3925 :
        Age = random.randint(30,39)
    elif nb_age<0.635 :
        Age = random.randint(40,49)
    elif nb_age<0.8275 :
        Age = random.randint(50,59)
    else :
        Age = random.randint(60,80)
    nb_sp = random.random() ; sp = 'N'
    if Age<18 :
        sp = 'ado'
    else :
        if nb_sp<0.09 :
            sp = 'chomeur'
        if sp == 'N' :
            nb_sp = random.random()
            if 18<=Age<=24 :
                if nb_sp<0.5 :
                    sp = 'etu'
            elif Age<=29 :
                if 0.5<=nb_sp<0.56 :
                    sp = 'etu'
            if sp == 'N' :
                if g == 'h' :
                    if Age<30 :
                        if nb_sp<0.01 :
                            sp = 'agri'
                        elif nb_sp<0.03 :
                            sp = 'ceo'
                        elif nb_sp<0.14 :
                            sp = 'cadre'
                        elif nb_sp<0.34 :
                            sp = 'pro_interm'
                        elif nb_sp<0.51 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<40 :
                        if nb_sp<0.04 :
                            sp = 'agri'
                        elif nb_sp<0.1 :
                            sp = 'ceo'
                        elif nb_sp<0.26 :
                            sp = 'cadre'
                        elif nb_sp<0.47 :
                            sp = 'pro_interm'
                        elif nb_sp<0.61 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<50 :
                        if nb_sp<0.04 :
                            sp = 'agri'
                        elif nb_sp<0.12 :
                            sp = 'ceo'
                        elif nb_sp<0.27 :
                            sp = 'cadre'
                        elif nb_sp<0.49 :
                            sp = 'pro_interm'
                        elif nb_sp<0.62 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<60 :
                        if nb_sp<0.05 :
                            sp = 'agri'
                        elif nb_sp<0.16 :
                            sp = 'ceo'
                        elif nb_sp<0.36 :
                            sp = 'cadre'
                        elif nb_sp<0.6 :
                            sp = 'pro_interm'
                        elif nb_sp<0.69 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<66 :
                        if nb_sp<0.1 :
                            sp = 'agri'
                        elif nb_sp<0.22 :
                            sp = 'ceo'
                        elif nb_sp<0.39 :
                            sp = 'cadre'
                        elif nb_sp<0.6 :
                            sp = 'pro_interm'
                        elif nb_sp<0.69 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    else : 
                        sp = 'retraite'
                else :
                    if Age<30 :
                        if nb_sp<0.002 :
                            sp = 'agri'
                        elif nb_sp<0.012 :
                            sp = 'ceo'
                        elif nb_sp<0.092 :
                            sp = 'cadre'
                        elif nb_sp<0.312 :
                            sp = 'pro_interm'
                        elif nb_sp<0.832 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<40 :
                        if nb_sp<0.01 :
                            sp = 'agri'
                        elif nb_sp<0.03 :
                            sp = 'ceo'
                        elif nb_sp<0.14 :
                            sp = 'cadre'
                        elif nb_sp<0.35 :
                            sp = 'pro_interm'
                        elif nb_sp<0.86 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<50 :
                        if nb_sp<0.02 :
                            sp = 'agri'
                        elif nb_sp<0.06 :
                            sp = 'ceo'
                        elif nb_sp<0.15 :
                            sp = 'cadre'
                        elif nb_sp<0.36 :
                            sp = 'pro_interm'
                        elif nb_sp<0.85 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<60 :
                        if nb_sp<0.03 :
                            sp = 'agri'
                        elif nb_sp<0.08 :
                            sp = 'ceo'
                        elif nb_sp<0.2 :
                            sp = 'cadre'
                        elif nb_sp<0.41 :
                            sp = 'pro_interm'
                        elif nb_sp<0.84 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<66 :
                        if nb_sp<0.1 :
                            sp = 'agri'
                        elif nb_sp<0.19 :
                            sp = 'ceo'
                        elif nb_sp<0.25 :
                            sp = 'cadre'
                        elif nb_sp<0.39 :
                            sp = 'pro_interm'
                        elif nb_sp<0.8 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    else : 
                        sp = 'retraite'
    nb_c = random.random()
    if Age<30 :
        if nb_c<0.01 :
            c = 'ill'
        else :
            c = 'healthy'
    elif Age<50 :
        nb_c = random.random()
        if nb_c<0.1 :
            c = 'ill'
        else :
            c = 'healthy'
    elif Age<65 :
        nb_c = random.random()
        if nb_c<0.4 :
            c = 'ill'
        else : 
            c = 'healthy'
    else :
        nb_c = random.random()
        if nb_c<0.7 :
            c = 'ill'
        else : 
            c = 'healthy'
    nb_f = random.random()
    if Age<20 :
        l = 0.39 
        if c == 'ill' :
            l = l/2 
            if nb_f<l :
                f = True
            else :
                f = False
        else :
            l = 1.2*l
            if nb_f<l :
                f = True
            else :
                f = False
    elif Age<26 :
        nb_f = random.random()
        l = 0.45
        if c == 'ill' :
            l = l/3
            if nb_f<l :
                f = True
            else :
                f = False
        else :
            l = 1.2*l
            if nb_f<l :
                f = True
            else :
                f = False
        
    elif Age<50 :
        nb_f = random.random()
        l = 0.27
        if c == 'ill' :
            l = l/3 
            if nb_f<l :
                f = True
            else :
                f = False
        else :
            l = 1.1*l
            if nb_f<l :
                f = True
            else :
                f = False
    elif Age<60 :
        if g == 'h':
            nb_f = random.random()
            l = 0.17
            if c == 'ill' :
                l = l/7
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 1.2*l
                if nb_f<l :
                    f = True
                else :
                    f = False
        else :
            nb_f = random.random()
            l = 0.08
            if c == 'ill' :
                l = l/8 
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 1.3*l
                if nb_f<l :
                    f = True
                else :
                    f = False
    else :
        if g == 'h':
            nb_f = random.random()
            l = 0.12
            if c == 'ill' :
                l = l/7
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 2*l
                if nb_f<l :
                    f = True
                else :
                    f = False
        else :
            nb_f = random.random()
            l = 0.05
            if c == 'ill' :
                l = l/10 
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 1.2*l
                if nb_f<l :
                    f = True
                else :
                    f = False
    if sp == 'ceo' or sp == 'cadre':
        if f == False :
            if c == 'healthy':
                if g == 'h':
                    fume = random.random()
                    if fume<0.094:
                        f = True
                else :
                    fume = random.random()
                    if fume<0.074:
                        f = True
            else :
                if g == 'h':
                    fume = random.random()
                    if fume<0.05:
                        f = True
                else :
                    fume = random.random()
                    if fume<0.03:
                        f = True
    if f :
        color = 'red'
    else : 
        color = 'white'
    nb_essai_arret = 0 ; nb_pub = 0 ; nb_lutte = 0   
           
    return [X,Y,color,Age,g,sp,c,nb_essai_arret,nb_pub,nb_lutte,f]

# %%
def create_pop(n):
    pop = []
    for i in range (n) :
        pop.append(person())
    return pop

# %%
def interaction_proche(pop):
    proche = []
    for i in range(len(pop)):
        proche.append([])
    for i in range (len(pop)):
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        dist = [np.sqrt((x_val[i] - x[0])**2 + (y_val[i] - x[1])**2) for x in pop]
        pgeo_i = [dist.index(j) for j in dist if j < 20]
        psoc_i = []
        for j in range(len(pgeo_i)):
            if i != j and j not in proche[i]:
                pi = pop[i]
                pj = pop[j]
                inter = random.random()
                if pi[5] == pj[5]:
                    if pi[3]-pj[3]<5:
                        if inter < 0.9:
                            proche[i].append(j)
                            proche[j].append(i)
                    elif pi[3]-pj[3]<15:
                        if inter < 0.5:
                            proche[i].append(j)
                            proche[j].append(i)
                    else:
                        if inter < 0.2:
                            proche[i].append(j)
                            proche[j].append(i)
                        
                else:
                    if pi[3]-pj[3]<5:
                        if inter < 0.3:
                            proche[i].append(j)
                            proche[j].append(i)
                    elif pi[3]-pj[3]<15:
                        if inter < 0.1:
                            proche[i].append(j)
                            proche[j].append(i)
                    else:
                        if inter < 0.03:
                            proche[i].append(j)
                            proche[j].append(i)


    i=0
    while i<len(proche):
        for j in proche[i]:
            change=[]
            if pop[j][-1]:
                for a in proche[i]:
                    if pop[a][-1]==False :
                        change.append(a)
            fume = random.random()
            if fume<0.3 :
                p = math.floor(len(change)*random.random())
                pop[p][-1]=True
                pop[p][2]='red'
        i=i+1

# %%
def debute_age_sponta(pop):  #chaque année
    for i in range(len(pop)) :
        if pop[i][-4]<4:
            if 15<=pop[i][3]<=30 :
                if pop[i][-1]==False :
                    fume = random.random()
                    if fume<0.4 :
                        pop[i][-1]=True
                        pop[i][2]='red'
                        ar = random.random()
                        if ar<0.65:
                            pop[i][-1]=False
                            pop[i][2]='white'
                    
                    
            else :
                if pop[4]=='h':
                    if pop[i][-1]==False and pop[i][6]=='healthy' :
                        fume = random.random()
                        if fume<0.2 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                            ar = random.random()
                            if ar<0.55:
                                pop[i][-1]=False
                                pop[i][2]='white'
                else :
                    if pop[i][-1]==False and pop[i][6]=='healthy' :
                        fume = random.random()
                        if fume<0.15 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                            ar = random.random()
                            if ar<0.5:
                                pop[i][-1]=False
                                pop[i][2]='white'

# %%
def arret_reprise_sponta(pop): #chaque année
    for i in range(len(pop)) :
        if pop[i][-1]:
            if pop[i][-4]<4:
                if pop[i][6]=='ill' :
                    n = random.random()
                    if n<0.5 : #arrêt d'un an au moins, on peut considérer 
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        reprise = random.random()
                        if reprise<0.45 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                        else :
                            pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre 
                else :
                    if pop[i][5]=='ceo' or pop[i][5]=='cadre' or pop[i][3]>50 :
                        n = random.random()
                        if n<0.1 : #arrêt d'un an au moins, on peut considérer 
                            pop[i][-4]=pop[i][-4]+1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.6 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                            else :
                                pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre
                    else :
                        n = random.random()
                        if n<0.045 : #arrêt d'un an au moins, on peut considérer 
                            pop[i][-4]=pop[i][-4]+1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.7 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                            else :
                                pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre

# %%
def arret_reprise_sponta(pop): #chaque année
    for i in range(len(pop)) :
        if pop[i][-1]:
            if pop[i][-4]<4:
                if pop[i][6]=='ill' :
                    n = random.random()
                    if n<0.5 : #arrêt d'un an au moins, on peut considérer 
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        reprise = random.random()
                        if reprise<0.45 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                        else :
                            pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre 
                else :
                    if pop[i][5]=='ceo' or pop[i][5]=='cadre' or pop[i][3]>50 :
                        n = random.random()
                        if n<0.1 : #arrêt d'un an au moins, on peut considérer 
                            pop[i][-4]=pop[i][-4]+1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.6 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                            else :
                                pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre
                    else :
                        n = random.random()
                        if n<0.045 : #arrêt d'un an au moins, on peut considérer 
                            pop[i][-4]=pop[i][-4]+1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.7 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                            else :
                                pop[i][-4]=4 #arrêt définitif, ils sont réussi à ne pas reprendre

# %%
def diffu_pub(pop):
    radio = random.random()
    tv = random.random()
    reseau = random.random() 
    n = random.random()
    for i in range(len(pop)) :
        if pop[i][3]<41 :
            l = 6
        else :
            l = 10
        if pop[i][-2]<l:
            if radio<0.3:
                pop[i][-3]=pop[i][-3]+1
            if tv<0.25:
                pop[i][-3]=pop[i][-3]+1
            if pop[i][3]<60:
                if reseau<0.8:
                    pop[i][-3]=pop[i][-3]+1
            else:
                if reseau<0.2:
                    pop[i][-3]=pop[i][-3]+1
        if pop[i][-4]<4 :
            if pop[i][-1]:
                if pop[i][-3]>=l/2:
                    if n<0.11 :
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=False
                        pop[i][2]='white'
                else :
                    if n<0.05 :
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=False
                        pop[i][2]='white'

# %%
def diffu_lutte(pop):
    for i in range(len(pop)) :
        if pop[i][3]<41 :
            l = 6
        else :
            l = 10
        vu = random.random()
        if pop[i][-2]<l:
            if vu<0.25:
                pop[i][-2]=pop[i][-2]+1
        if pop[i][-4]<4 :
            if pop[i][-1]:
                n = random.random()
                if pop[i][-2]>=l/2:
                    if n<0.65 :
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        reprise = random.random()
                        if pop[i][-4]<4 :
                            if reprise<0.4 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                else :
                    if n<0.3 :
                        pop[i][-4]=pop[i][-4]+1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        reprise = random.random()
                        if pop[i][-4]<4 :
                            if reprise<0.7 :
                                pop[i][-1]=True
                                pop[i][2]='red'

# %%
def affiche(pop, date = 0, titre = ''):
    
    fig = plt.figure(figsize = (8,6))
    
    x_val = [x[0] for x in pop]
    y_val = [x[1] for x in pop]
    color = [x[2] for x in pop]
            
    plt.scatter(x_val,y_val, c = color, edgecolors = 'black', s = 60)

    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    
    year = 2022 + date
    if titre == '':
        plt.title(str(year))
    else:
        plt.title(titre)

    plt.xlim(-1,101)
    plt.ylim(-1,101)
    plt.show()
    
    nbf = (sum(bool(x[-1]) for x in pop))*100/len(pop)
    print(str(nbf) + "% de fumeur")

# %%
def pop_init(nb):
    pop = create_pop(nb)
    nbf = [(sum(bool(x[-1]) for x in pop))*100/len(pop)]
    date = 0
    
    return pop

pop = pop_init(1000)
affiche(pop)
# Out:
# 24.8% de fumeur

# %%
def year(pop):
    for i in range(len(pop)):
        pop[i][0] += random.randint(-5,5) 
        if pop[i][0]<0:
            pop[i][0] = random.randint(0,5)
        elif pop[i][0]>100:
            pop[i][0] = random.randint(95,100)
            
        pop[i][1] += random.randint(-5,5)
        if pop[i][1]<0:
            pop[i][1] = random.randint(0,5)
        elif pop[i][1]>100:
            pop[i][1] = random.randint(95,100)
            
    debute_age_sponta(pop)
    arret_reprise_sponta(pop)
    diffu_pub(pop)
    diffu_lutte(pop)
    interaction_proche(pop)
        
    return pop

# %%
def year_sans_pub(pop):
    for i in range(len(pop)):
        pop[i][0] += random.randint(-5,5) 
        if pop[i][0]<0:
            pop[i][0] = random.randint(0,5)
        elif pop[i][0]>100:
            pop[i][0] = random.randint(95,100)
            
        pop[i][1] += random.randint(-5,5)
        if pop[i][1]<0:
            pop[i][1] = random.randint(0,5)
        elif pop[i][1]>100:
            pop[i][1] = random.randint(95,100)
            
    debute_age_sponta(pop)
    arret_reprise_sponta(pop)
    diffu_lutte(pop)
    interaction_proche(pop)
        
    return pop

# %%
def year_sans_interaction(pop):
    for i in range(len(pop)):
        pop[i][0] += random.randint(-5,5) 
        if pop[i][0]<0:
            pop[i][0] = random.randint(0,5)
        elif pop[i][0]>100:
            pop[i][0] = random.randint(95,100)
            
        pop[i][1] += random.randint(-5,5)
        if pop[i][1]<0:
            pop[i][1] = random.randint(0,5)
        elif pop[i][1]>100:
            pop[i][1] = random.randint(95,100)
            
    debute_age_sponta(pop)
    arret_reprise_sponta(pop)
    diffu_pub(pop)
    diffu_lutte(pop)
        
    return pop

# %%
def affiche_simulation(nb_pop, nb_year):
    
    pop = pop_init(nb_pop)
    date = 0
    nbf = [sum(bool(x[10]) for x in pop)/len(pop)*100]
    affiche(pop,date)


    for i in range(1,nb_year+1):
        pop = year(pop)
        date += 1
        nbf.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        color = [x[2] for x in pop]
        
    affiche(pop,date)
    
    x = np.linspace(2022,2022+nb_year,nb_year+1)
    plt.plot(x,nbf)
    axes = plt.gca()
    axes.set_xlabel('Date')
    axes.set_ylabel('% de fumeur')
    plt.ylim(0,100)
    plt.xlim(2022,2022+nb_year)
    plt.show()

# %%
affiche_simulation(1000,10)
# Out:
# 21.9% de fumeur
# 27.7% de fumeur

# %%
def stat(pop, nb_pop, nb_year):
    
    date = 0
    nbf = [sum(bool(x[10]) for x in pop)/len(pop)*100]


    for i in range(1,nb_year+1):
        pop = year(pop)
        date += 1
        nbf.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        color = [x[2] for x in pop]
    
    return nbf

# %%
def stat_sans_pub(pop, nb_pop, nb_year):
    
    date = 0
    nbf_sp = [sum(bool(x[10]) for x in pop)/len(pop)*100]


    for i in range(1,nb_year+1):
        pop = year_sans_pub(pop)
        date += 1
        nbf_sp.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        color = [x[2] for x in pop]
    
    return nbf_sp

# %%
def stat_sans_interaction(pop, nb_pop, nb_year):
    
    date = 0
    nbf_si = [sum(bool(x[10]) for x in pop)/len(pop)*100]


    for i in range(1,nb_year+1):
        pop = year_sans_interaction(pop)
        date += 1
        nbf_si.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        color = [x[2] for x in pop]
    
    return nbf_si

# %%
def simulations(nb_pop, nb_year, nb_xps = 1):
    
    nbf = [0]*nb_year
    nbf_sp = [0]*nb_year
    nbf_si = [0]*nb_year
    
    for _ in range(nb_xps):
        pop = create_pop(nb_pop)
        pop1 = pop
        pop2 = pop
        pop3 = pop
        
        affiche(pop, titre = 'Pop initiale (2022)')
        stats = stat(pop1, nb_pop, nb_year)
        stat_sp = stat_sans_pub(pop2, nb_pop, nb_year)
        stat_si = stat_sans_interaction(pop3, nb_pop, nb_year)
        for i in range(0,nb_year):
            nbf[i]+=stats[i]
            nbf_sp[i]+=stat_sp[i]
            nbf_si[i]+=stat_si[i]
            
        affiche(pop1, titre = 'Avec pub et avec interaction')
        affiche(pop2, titre = 'Sans pub et avec interaction')
        affiche(pop3, titre = 'Avec pub et sans interaction')
            
    for f in range(nb_year):
        nbf[f] = nbf[f]/nb_xps
        nbf_sp[f] = nbf_sp[f]/nb_xps
        nbf_si[f] = nbf_si[f]/nb_xps
        
    x = np.linspace(2022,2022+nb_year,nb_year)
    
    fig = plt.figure(figsize = (10,5))
    plt.plot(x, nbf, c = 'red', alpha=0.5, label = 'avec pub')
    plt.plot(x, nbf_sp, c = 'green', alpha=0.5, label = 'sans pub')
    plt.plot(x, nbf_si, c = 'blue', alpha=0.5, label = 'sans interaction')
    
    
    axes = plt.gca()
    axes.set_xlabel('Date')
    axes.set_ylabel('% de fumeur')
    plt.ylim(0,100)
    plt.xlim(2022,2022+nb_year)
    plt.legend()
    plt.show()

# %%
simulations(1000,20,1)
# Out:
# 23.6% de fumeur
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-203-98045a7c8112> in <module>
# ----> 1 simulations(1000,20,1)
#
# <ipython-input-202-4629a0bb235f> in simulations(nb_pop, nb_year, nb_xps)
#      13         affiche(pop, titre = 'Pop initiale (2022)')
#      14         stats = stat(pop1, nb_pop, nb_year)
# ---> 15         stat_sp = stat_sans_pub(pop2, nb_pop, nb_year)
#      16         stat_si = stat_sans_interaction(pop3, nb_pop, nb_year)
#      17         for i in range(0,nb_year):
#
# <ipython-input-138-21303e910c4f> in stat_sans_pub(pop, nb_pop, nb_year)
#       6
#       7     for i in range(1,nb_year+1):
# ----> 8         pop = year_sans_pub(pop)
#       9         date += 1
#      10         nbf_sp.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
#
# <ipython-input-86-157e01d2677d> in year_sans_pub(pop)
#      16     arret_reprise_sponta(pop)
#      17     diffu_lutte(pop)
# ---> 18     interaction_proche(pop)
#      19
#      20     return pop
#
# <ipython-input-77-a79935308053> in interaction_proche(pop)
#      11         for j in range(len(pgeo_i)):
#      12             if i != j and j not in proche[i]:
# ---> 13                 pi = pop[i]
#      14                 pj = pop[j]
#      15                 inter = random.random()
#
# KeyboardInterrupt:
