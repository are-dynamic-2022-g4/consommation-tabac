# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import random
import math
# %matplotlib inline

# %%
def person():
    genre = ['h','f']
    X = random.randint(0,100)
    Y = random.randint(0,100)
    g = genre[math.floor(2*random.random())]
    nb_age = random.random()
    if nb_age<0.16 :
        Age = random.randint(15,29)
    elif nb_age<0.3925 :
        Age = random.randint(30,39)
    elif nb_age<0.635 :
        Age = random.randint(40,49)
    elif nb_age<0.8275 :
        Age = random.randint(50,59)
    else :
        Age = random.randint(60,80)
    nb_sp = random.random() ; sp = 'N'
    if Age<18 :
        sp = 'ado'
    else :
        if nb_sp<0.09 :
            sp = 'chomeur'
        if sp == 'N' :
            nb_sp = random.random()
            if 18<=Age<=24 :
                if nb_sp<0.5 :
                    sp = 'etu'
            elif Age<=29 :
                if 0.5<=nb_sp<0.56 :
                    sp = 'etu'
            if sp == 'N' :
                if g == 'h' :
                    if Age<30 :
                        if nb_sp<0.01 :
                            sp = 'agri'
                        elif nb_sp<0.03 :
                            sp = 'ceo'
                        elif nb_sp<0.14 :
                            sp = 'cadre'
                        elif nb_sp<0.34 :
                            sp = 'pro_interm'
                        elif nb_sp<0.51 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<40 :
                        if nb_sp<0.04 :
                            sp = 'agri'
                        elif nb_sp<0.1 :
                            sp = 'ceo'
                        elif nb_sp<0.26 :
                            sp = 'cadre'
                        elif nb_sp<0.47 :
                            sp = 'pro_interm'
                        elif nb_sp<0.61 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<50 :
                        if nb_sp<0.04 :
                            sp = 'agri'
                        elif nb_sp<0.12 :
                            sp = 'ceo'
                        elif nb_sp<0.27 :
                            sp = 'cadre'
                        elif nb_sp<0.49 :
                            sp = 'pro_interm'
                        elif nb_sp<0.62 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<60 :
                        if nb_sp<0.05 :
                            sp = 'agri'
                        elif nb_sp<0.16 :
                            sp = 'ceo'
                        elif nb_sp<0.36 :
                            sp = 'cadre'
                        elif nb_sp<0.6 :
                            sp = 'pro_interm'
                        elif nb_sp<0.69 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<66 :
                        if nb_sp<0.1 :
                            sp = 'agri'
                        elif nb_sp<0.22 :
                            sp = 'ceo'
                        elif nb_sp<0.39 :
                            sp = 'cadre'
                        elif nb_sp<0.6 :
                            sp = 'pro_interm'
                        elif nb_sp<0.69 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    else : 
                        sp = 'retraite'
                else :
                    if Age<30 :
                        if nb_sp<0.002 :
                            sp = 'agri'
                        elif nb_sp<0.012 :
                            sp = 'ceo'
                        elif nb_sp<0.092 :
                            sp = 'cadre'
                        elif nb_sp<0.312 :
                            sp = 'pro_interm'
                        elif nb_sp<0.832 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<40 :
                        if nb_sp<0.01 :
                            sp = 'agri'
                        elif nb_sp<0.03 :
                            sp = 'ceo'
                        elif nb_sp<0.14 :
                            sp = 'cadre'
                        elif nb_sp<0.35 :
                            sp = 'pro_interm'
                        elif nb_sp<0.86 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<50 :
                        if nb_sp<0.02 :
                            sp = 'agri'
                        elif nb_sp<0.06 :
                            sp = 'ceo'
                        elif nb_sp<0.15 :
                            sp = 'cadre'
                        elif nb_sp<0.36 :
                            sp = 'pro_interm'
                        elif nb_sp<0.85 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<60 :
                        if nb_sp<0.03 :
                            sp = 'agri'
                        elif nb_sp<0.08 :
                            sp = 'ceo'
                        elif nb_sp<0.2 :
                            sp = 'cadre'
                        elif nb_sp<0.41 :
                            sp = 'pro_interm'
                        elif nb_sp<0.84 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    elif Age<66 :
                        if nb_sp<0.1 :
                            sp = 'agri'
                        elif nb_sp<0.19 :
                            sp = 'ceo'
                        elif nb_sp<0.25 :
                            sp = 'cadre'
                        elif nb_sp<0.39 :
                            sp = 'pro_interm'
                        elif nb_sp<0.8 :
                            sp = 'employe'
                        else : 
                            sp = 'ouvrier'
                    else : 
                        sp = 'retraite'
    nb_c = random.random()
    if Age<30 :
        if nb_c<0.01 :
            c = 'ill'
        else :
            c = 'healthy'
    elif Age<50 :
        nb_c = random.random()
        if nb_c<0.1 :
            c = 'ill'
        else :
            c = 'healthy'
    elif Age<65 :
        nb_c = random.random()
        if nb_c<0.4 :
            c = 'ill'
        else : 
            c = 'healthy'
    else :
        nb_c = random.random()
        if nb_c<0.7 :
            c = 'ill'
        else : 
            c = 'healthy'
    nb_f = random.random()
    if Age<20 :
        l = 0.39 
        if c == 'ill' :
            l = l/2 
            if nb_f<l :
                f = True
            else :
                f = False
        else :
            l = 1.2*l
            if nb_f<l :
                f = True
            else :
                f = False
    elif Age<26 :
        nb_f = random.random()
        l = 0.45
        if c == 'ill' :
            l = l/3
            if nb_f<l :
                f = True
            else :
                f = False
        else :
            l = 1.2*l
            if nb_f<l :
                f = True
            else :
                f = False
        
    elif Age<50 :
        nb_f = random.random()
        l = 0.27
        if c == 'ill' :
            l = l/3 
            if nb_f<l :
                f = True
            else :
                f = False
        else :
            l = 1.1*l
            if nb_f<l :
                f = True
            else :
                f = False
    elif Age<60 :
        if g == 'h':
            nb_f = random.random()
            l = 0.17
            if c == 'ill' :
                l = l/7
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 1.2*l
                if nb_f<l :
                    f = True
                else :
                    f = False
        else :
            nb_f = random.random()
            l = 0.08
            if c == 'ill' :
                l = l/8 
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 1.3*l
                if nb_f<l :
                    f = True
                else :
                    f = False
    else :
        if g == 'h':
            nb_f = random.random()
            l = 0.12
            if c == 'ill' :
                l = l/7
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 2*l
                if nb_f<l :
                    f = True
                else :
                    f = False
        else :
            nb_f = random.random()
            l = 0.05
            if c == 'ill' :
                l = l/10 
                if nb_f<l :
                    f = True
                else :
                    f = False
            else :
                l = 1.2*l
                if nb_f<l :
                    f = True
                else :
                    f = False
    if sp == 'ceo' or sp == 'cadre':
        if f == False :
            if c == 'healthy':
                if g == 'h':
                    fume = random.random()
                    if fume<0.094:
                        f = True
                else :
                    fume = random.random()
                    if fume<0.074:
                        f = True
            else :
                if g == 'h':
                    fume = random.random()
                    if fume<0.05:
                        f = True
                else :
                    fume = random.random()
                    if fume<0.03:
                        f = True
    if f :
        color = 'red'
    else : 
        color = 'white'
    arret_def = random.randint(3,5) ; nb_pub = 0 ; nb_lutte = 0   
           
    return [X,Y,color,Age,g,sp,c,arret_def,nb_pub,nb_lutte,f]

# %%
def create_pop(n):
    pop = []
    for i in range (n) :
        pop.append(person())
    return pop

# %%
def interaction_proche(pop):
    proche = []
    for i in range(len(pop)):
        proche.append([])
    for i in range (len(pop)):
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        dist = [np.sqrt((x_val[i] - x[0])**2 + (y_val[i] - x[1])**2) for x in pop]
        pgeo_i = [dist.index(j) for j in dist if j < 20]
        psoc_i = []
        for j in range(len(pgeo_i)):
            if i != j and j not in proche[i]:
                pi = pop[i]
                pj = pop[j]
                inter = random.random()
                if pi[5] == pj[5]:
                    if pi[3]-pj[3]<5:
                        if inter < 0.001:
                            proche[i].append(j)
                            proche[j].append(i)
                    elif pi[3]-pj[3]<15:
                        if inter < 0.0012:
                            proche[i].append(j)
                            proche[j].append(i)
                    else:
                        if inter < 0.0001:
                            proche[i].append(j)
                            proche[j].append(i)
                        
                else:
                    if pi[3]-pj[3]<5:
                        if inter < 0.0003:
                            proche[i].append(j)
                            proche[j].append(i)
                    elif pi[3]-pj[3]<15:
                        if inter < 0.00008:
                            proche[i].append(j)
                            proche[j].append(i)
                    else:
                        if inter < 0.00001:
                            proche[i].append(j)
                            proche[j].append(i)


    i=0
    while i<len(proche):
        for j in proche[i]:
            change=[]
            if pop[j][-1]:
                for a in proche[i]:
                    if pop[a][-1]==False :
                        change.append(a)
            fume = random.random()
            if fume<0.05 and len(change)>1:
                n=change[random.randint(0,len(change)-1)]
                if pop[n][-4]!=0:
                    pop[n][-1]=True
                    pop[n][2]='red'
        i=i+1

# %%
def debute_age_sponta(pop):  #chaque année
    for i in range(len(pop)) :
        if pop[i][-4]<4:
            if 15<=pop[i][3]<=30 :
                if pop[i][-1]==False :
                    fume = random.random()
                    if fume<0.4 :
                        pop[i][-1]=True
                        pop[i][2]='red'
                        ar = random.random()
                        if ar<0.65:
                            pop[i][-1]=False
                            pop[i][2]='white'
                    
                    
            else :
                if pop[4]=='h':
                    if pop[i][-1]==False and pop[i][6]=='healthy' :
                        fume = random.random()
                        if fume<0.2 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                            ar = random.random()
                            if ar<0.55:
                                pop[i][-1]=False
                                pop[i][2]='white'
                else :
                    if pop[i][-1]==False and pop[i][6]=='healthy' :
                        fume = random.random()
                        if fume<0.15 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                            ar = random.random()
                            if ar<0.5:
                                pop[i][-1]=False
                                pop[i][2]='white'

# %%
def arret_reprise_sponta(pop): #chaque année
    for i in range(len(pop)) :
        if pop[i][-1]:
            if pop[i][-4]>0:
                if pop[i][6]=='ill' :
                    n = random.random()
                    if n<0.8 :
                        pop[i][-4]=pop[i][-4]-1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        reprise = random.random()
                        if reprise<0.2 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                else :
                    if pop[i][5]=='ceo' or pop[i][5]=='cadre' or pop[i][3]>50 :
                        n = random.random()
                        if n<0.25 : #arrêt d'un an au moins
                            pop[i][-4]=pop[i][-4]-1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.55 :
                                pop[i][-1]=True
                                pop[i][2]='red'
                    else :
                        n = random.random()
                        if n<0.1 :
                            pop[i][-4]=pop[i][-4]-1
                            pop[i][-1]=False
                            pop[i][2]='white'
                            reprise = random.random()
                            if reprise<0.7 :
                                pop[i][-1]=True
                                pop[i][2]='red'

# %%
def diffu_pub(pop):
    radio = random.random()
    tv = random.random()
    reseau = random.random() 
    n = random.random()
    for i in range(len(pop)) :
        if pop[i][3]<41 :
            l = 8
        else :
            l = 12
        if pop[i][-2]<l:
            if radio<0.15:
                pop[i][-3]=pop[i][-3]+1
            if tv<0.25:
                pop[i][-3]=pop[i][-3]+1
            if pop[i][3]<60:
                if reseau<0.8:
                    pop[i][-3]=pop[i][-3]+1
            else:
                if reseau<0.2:
                    pop[i][-3]=pop[i][-3]+1
        if pop[i][-4]>0 :
            if pop[i][-1]==False:
                if pop[i][-3]>=l:
                    if n<0.25 :
                        pop[i][-1]=True
                        pop[i][2]='red'     
                elif pop[i][-3]>=l/2:
                    if n<0.011 :
                        pop[i][-1]=True
                        pop[i][2]='red' 
                        n=random.random()
                        if n<0.11 :
                            pop[i][-4]=pop[i][-4]-1
                            pop[i][-1]=False
                            pop[i][2]='white'
                else :
                    if n<0.005 :
                        pop[i][-1]=True
                        pop[i][2]='red'
                        n=random.random()
                        if n<0.5 :
                            pop[i][-4]=pop[i][-4]-1
                            pop[i][-1]=False
                            pop[i][2]='white'

# %%
def diffu_pub_jeune(pop):
    radio = random.random()
    tv = random.random()
    reseau = random.random() 
    n = random.random()
    l=8
    for i in range(0,len(pop)):
        if pop[i][3]<30:
            if pop[i][-2]<l:
                if radio<0.15:
                    pop[i][-3]=pop[i][-3]+1
                if tv<0.25:
                    pop[i][-3]=pop[i][-3]+1
                if reseau<0.8:
                    pop[i][-3]=pop[i][-3]+1
                if pop[i][-4]>0 :
                    if pop[i][-1]==False:
                        if pop[i][-3]>=l:
                            if n<0.35 :
                                pop[i][-1]=True
                                pop[i][2]='red'     
                        elif pop[i][-3]>=l/2:
                            if n<0.09 :
                                pop[i][-1]=True
                                pop[i][2]='red' 
                                n=random.random()
                                if n<0.09 :
                                    pop[i][-4]=pop[i][-4]-1
                                    pop[i][-1]=False
                                    pop[i][2]='white'
                    else :
                        if n<0.05 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                            n=random.random()
                            if n<0.3 :
                                pop[i][-4]=pop[i][-4]-1
                                pop[i][-1]=False
                                pop[i][2]='white'

# %%
def diffu_pub_v(pop):
    radio = random.random()
    tv = random.random()
    reseau = random.random() 
    n = random.random()
    l=12
    for i in range(0,len(pop)):
        if pop[i][3]>=30:
            if pop[i][-2]<l:
                if radio<0.35:
                    pop[i][-3]=pop[i][-3]+1
                if tv<0.3:
                    pop[i][-3]=pop[i][-3]+1
                if reseau<0.5:
                    pop[i][-3]=pop[i][-3]+1
                if pop[i][-4]>0 :
                    if pop[i][-1]==False:
                        if pop[i][-3]>=l:
                            if n<0.2 :
                                pop[i][-1]=True
                                pop[i][2]='red'     
                        elif pop[i][-3]>=l/2:
                            if n<0.05 :
                                pop[i][-1]=True
                                pop[i][2]='red' 
                                n=random.random()
                                if n<0.09 :
                                    pop[i][-4]=pop[i][-4]-1
                                    pop[i][-1]=False
                                    pop[i][2]='white'
                    else :
                        if n<0.01 :
                            pop[i][-1]=True
                            pop[i][2]='red'
                            n=random.random()
                            if n<0.3 :
                                pop[i][-4]=pop[i][-4]-1
                                pop[i][-1]=False
                                pop[i][2]='white'

# %%
def diffu_lutte(pop):
    for i in range(len(pop)) :
        if pop[i][3]<41 :
            l = 4
        else :
            l = 6
        vu = random.random()
        if pop[i][-2]<l:
            if vu<0.25:
                pop[i][-2]=pop[i][-2]+1
        if pop[i][-4]>0 :
            if pop[i][-1]:
                n = random.random()
                if pop[i][-2]>=l:
                    if n<0.85 :
                        pop[i][-4]=pop[i][-4]-1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        if pop[i][-4]>0 :#parmi ceux qui ont vu plusieurs fois la campagne
                            if n<0.1 : #si elle a échoué
                                pop[i][-1]=True
                                pop[i][2]='red'
                elif pop[i][-2]>=l/2:
                    if n<0.5 :
                        pop[i][-4]=pop[i][-4]-1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        if pop[i][-4]>0 :#parmi ceux qui ont vu plusieurs fois la campagne
                            if n<0.4 : #si elle a échoué
                                pop[i][-1]=True
                                pop[i][2]='red'
                else :
                    if n<0.2 :
                        pop[i][-4]=pop[i][-4]-1
                        pop[i][-1]=False
                        pop[i][2]='white'
                        pop[i][-5]=1
                        if pop[i][-4]>0 :
                            n = random.random()
                            if n<0.65 :
                                pop[i][-1]=True
                                pop[i][2]='red'

# %%
def affiche(pop, date = 0, titre = ''):
    
    fig = plt.figure(figsize = (6,6))
    
    x_val = [x[0] for x in pop]
    y_val = [x[1] for x in pop]
    color = [x[2] for x in pop]
            
    plt.scatter(x_val,y_val, c = color, edgecolors = 'black')

    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    
    year = 2022 + date
    if titre == '':
        plt.title(str(year))
    else:
        plt.title(titre)

    plt.xlim(-1,101)
    plt.ylim(-1,101)
    plt.show()
    
    nbf = (sum(bool(x[-1]) for x in pop))*100/len(pop)
    print(str(nbf) + "% de fumeur")

# %%
def pop_init(nb):
    pop = create_pop(nb)
    nbf = [(sum(bool(x[-1]) for x in pop))*100/len(pop)]
    date = 0
    
    return pop

pop = pop_init(1000)
affiche(pop)
# Out:
# 24.7% de fumeur

# %%
def year(pop):
    for i in range(len(pop)):
        pop[i][0] += random.randint(-5,5) 
        if pop[i][0]<0:
            pop[i][0] = random.randint(0,5)
        elif pop[i][0]>100:
            pop[i][0] = random.randint(95,100)
            
        pop[i][1] += random.randint(-5,5)
        if pop[i][1]<0:
            pop[i][1] = random.randint(0,5)
        elif pop[i][1]>100:
            pop[i][1] = random.randint(95,100)
    
    interaction_proche(pop)
    debute_age_sponta(pop)
    arret_reprise_sponta(pop)
    diffu_pub(pop)
    diffu_lutte(pop)

# %%
def year_sans_pub(pop):
    for i in range(len(pop)):
        pop[i][0] += random.randint(-5,5) 
        if pop[i][0]<0:
            pop[i][0] = random.randint(0,5)
        elif pop[i][0]>100:
            pop[i][0] = random.randint(95,100)
            
        pop[i][1] += random.randint(-5,5)
        if pop[i][1]<0:
            pop[i][1] = random.randint(0,5)
        elif pop[i][1]>100:
            pop[i][1] = random.randint(95,100)
    interaction_proche(pop)      
    debute_age_sponta(pop)
    arret_reprise_sponta(pop)
    diffu_lutte(pop)

# %%
def year_sans_interaction(pop):
    for i in range(len(pop)):
        pop[i][0] += random.randint(-5,5) 
        if pop[i][0]<0:
            pop[i][0] = random.randint(0,5)
        elif pop[i][0]>100:
            pop[i][0] = random.randint(95,100)
            
        pop[i][1] += random.randint(-5,5)
        if pop[i][1]<0:
            pop[i][1] = random.randint(0,5)
        elif pop[i][1]>100:
            pop[i][1] = random.randint(95,100)
            
    debute_age_sponta(pop)
    arret_reprise_sponta(pop)
    diffu_pub(pop)
    diffu_lutte(pop)

# %%
def year_pub_jeune(pop):
    for i in range(len(pop)):
        pop[i][0] += random.randint(-5,5) 
        if pop[i][0]<0:
            pop[i][0] = random.randint(0,5)
        elif pop[i][0]>100:
            pop[i][0] = random.randint(95,100)
            
        pop[i][1] += random.randint(-5,5)
        if pop[i][1]<0:
            pop[i][1] = random.randint(0,5)
        elif pop[i][1]>100:
            pop[i][1] = random.randint(95,100)
    interaction_proche(pop)       
    debute_age_sponta(pop)
    arret_reprise_sponta(pop)
    diffu_pub_jeune(pop)
    diffu_lutte(pop)

# %%
def year_pub_v(pop):
    for i in range(len(pop)):
        pop[i][0] += random.randint(-5,5) 
        if pop[i][0]<0:
            pop[i][0] = random.randint(0,5)
        elif pop[i][0]>100:
            pop[i][0] = random.randint(95,100)
            
        pop[i][1] += random.randint(-5,5)
        if pop[i][1]<0:
            pop[i][1] = random.randint(0,5)
        elif pop[i][1]>100:
            pop[i][1] = random.randint(95,100)
            
    interaction_proche(pop)       
    debute_age_sponta(pop)
    arret_reprise_sponta(pop)
    diffu_pub_v(pop)
    diffu_lutte(pop)

# %%
def affiche_simulation(nb_pop, nb_year):
    
    pop = pop_init(nb_pop)
    date = 0
    nbf = [sum(bool(x[10]) for x in pop)/len(pop)*100]
    affiche(pop,date)


    for i in range(1,nb_year+1):
        year(pop)
        date += 1
        nbf.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        color = [x[2] for x in pop]
        
    affiche(pop,date)
    
    x = np.linspace(2022,2022+nb_year,nb_year+1)
    plt.plot(x,nbf)
    axes = plt.gca()
    axes.set_xlabel('Date')
    axes.set_ylabel('% de fumeur')
    plt.ylim(0,100)
    plt.xlim(2022,2022+nb_year)
    plt.show()

# %%
affiche_simulation(100,10)
# Out:
# 22.0% de fumeur
# 26.0% de fumeur

# %%
def stat(pop, nb_pop, nb_year):
    
    date = 0
    nbf = [sum(bool(x[10]) for x in pop)/len(pop)*100]


    for i in range(1,nb_year+1):
        year(pop)
        date += 1
        nbf.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        color = [x[2] for x in pop]
    
    return nbf

# %%
def stat_sans_pub(pop, nb_pop, nb_year):
    
    date = 0
    nbf_sp = [sum(bool(x[10]) for x in pop)/len(pop)*100]


    for i in range(1,nb_year+1):
        year_sans_pub(pop)
        date += 1
        nbf_sp.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        color = [x[2] for x in pop]
    
    return nbf_sp

# %%
def stat_sans_interaction(pop, nb_pop, nb_year):
    
    date = 0
    nbf_si = [sum(bool(x[10]) for x in pop)/len(pop)*100]


    for i in range(1,nb_year+1):
        year_sans_interaction(pop)
        date += 1
        nbf_si.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        color = [x[2] for x in pop]
    
    return nbf_si

# %%
def stat_pub_jeune(pop, nb_pop, nb_year):
    date = 0
    nbf_pj = [sum(bool(x[10]) for x in pop)/len(pop)*100]


    for i in range(1,nb_year+1):
        year_pub_jeune(pop)
        date += 1
        nbf_pj.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        color = [x[2] for x in pop]
    
    return nbf_pj

# %%
def stat_pub_v(pop, nb_pop, nb_year):
    date = 0
    nbf_pv = [sum(bool(x[10]) for x in pop)/len(pop)*100]


    for i in range(1,nb_year+1):
        year_pub_v(pop)
        date += 1
        nbf_pv.append(sum(bool(x[-1]) for x in pop)/len(pop)*100)
        x_val = [x[0] for x in pop]
        y_val = [x[1] for x in pop]
        color = [x[2] for x in pop]
    
    return nbf_pv

# %%
def affiche_res(pop,pop1,pop2,pop3,pop4,pop5,nb_year):
    
    fig = plt.figure(figsize = (16,16))
    
    #Pop initiale
    x_val = [x[0] for x in pop]
    y_val = [x[1] for x in pop]
    color = [x[2] for x in pop]
    
    plt.subplot(321)
    plt.scatter(x_val,y_val, c = color, edgecolors = 'black', s = 60)

    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    
    plt.title('Pop initiale (2022)')

    plt.xlim(-1,101)
    plt.ylim(-1,101)
    
    #Pop finale
    x_val_fin = [x[0] for x in pop1]
    y_val_fin = [x[1] for x in pop1]
    color_fin = [x[2] for x in pop1]
    
    plt.subplot(322)
    plt.scatter(x_val_fin,y_val_fin, c = color_fin, edgecolors = 'black', s = 60)

    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    
    plt.title('Pop finale ('+str(2022+nb_year)+')')

    plt.xlim(-1,101)
    plt.ylim(-1,101)
    
    #Pop sans pub
    x_val_sp = [x[0] for x in pop2]
    y_val_sp = [x[1] for x in pop2]
    color_sp = [x[2] for x in pop2]
    
    plt.subplot(323)
    plt.scatter(x_val_sp,y_val_sp, c = color_sp, edgecolors = 'black', s = 60)

    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    
    plt.title('Pop finale sans pub')

    plt.xlim(-1,101)
    plt.ylim(-1,101)
    
    
    #Pop sans interaction
    x_val_si = [x[0] for x in pop3]
    y_val_si = [x[1] for x in pop3]
    color_si = [x[2] for x in pop3]
    
    plt.subplot(324)
    plt.scatter(x_val_si,y_val_si, c = color_si, edgecolors = 'black', s = 60)

    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    
    plt.title('Pop finale sans interaction')
    
    #Pop avec pub dirigée sur les jeunes
    x_val_pj = [x[0] for x in pop4]
    y_val_pj = [x[1] for x in pop4]
    color_pj = [x[2] for x in pop4]
    
    plt.subplot(325)
    plt.scatter(x_val_pj,y_val_pj, c = color_pj, edgecolors = 'black', s = 60)

    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    
    plt.title('Pop finale avec pub dirigée sur les jeunes')
    
    #Pop avec pub dirigée sur les plus de 30 ans
    x_val_pv = [x[0] for x in pop5]
    y_val_pv = [x[1] for x in pop5]
    color_pv = [x[2] for x in pop5]
    
    plt.subplot(326)
    plt.scatter(x_val_pv,y_val_pv, c = color_pv, edgecolors = 'black', s = 60)

    ax = plt.gca()
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    
    plt.title('Pop finale avec pub dirigée sur les plus de 30 ans')

    plt.xlim(-1,101)
    plt.ylim(-1,101)
    
    plt.savefig("pop finale.png")

# %%
def simulations(nb_pop, nb_year, nb_xps = 1):
    
    nbf = [0]*(nb_year+1)
    nbf_sp = [0]*(nb_year+1)
    nbf_si = [0]*(nb_year+1)
    nbf_pj = [0]*(nb_year+1)
    nbf_pv = [0]*(nb_year+1)
    
    for _ in range(nb_xps):
        pop0 = create_pop(nb_pop)
        pop1 = create_pop(nb_pop)
        pop2 = create_pop(nb_pop)
        pop3 = create_pop(nb_pop)
        pop4 = create_pop(nb_pop)
        pop5 = create_pop(nb_pop)
        
        #nbf[0] = sum(bool(x[10]) for x in pop0)/len(pop)*100
        #nbf_sp[0] = sum(bool(x[10]) for x in pop0)/len(pop)*100
        #nbf_si[0] = sum(bool(x[10]) for x in pop0)/len(pop)*100
        
        stats = stat(pop1, nb_pop, nb_year)
        stat_sp = stat_sans_pub(pop2, nb_pop, nb_year)
        stat_si = stat_sans_interaction(pop3, nb_pop, nb_year)
        stat_pj = stat_pub_jeune(pop4, nb_pop, nb_year)
        stat_pv = stat_pub_v(pop5, nb_pop, nb_year)
        for i in range(nb_year+1):
            nbf[i]+=stats[i]
            nbf_sp[i]+=stat_sp[i]
            nbf_si[i]+=stat_si[i]
            nbf_pj[i]+=stat_pj[i]
            nbf_pv[i]+=stat_pv[i]
            
        affiche_res(pop0,pop1,pop2,pop3,pop4,pop5,nb_year)
            
    #for f in range(nb_year):
    #    nbf[f] = nbf[f]/nb_xps
    #    nbf_sp[f] = nbf_sp[f]/nb_xps
    #    nbf_si[f] = nbf_si[f]/nb_xps
    
    x = np.linspace(2022,2022+nb_year,nb_year+1)
    
    fig = plt.figure(figsize = (10,5))
    plt.plot(x, nbf, c = 'red', alpha=0.5, label = 'avec pub')
    plt.plot(x, nbf_sp, c = 'green', alpha=0.5, label = 'sans pub')
    plt.plot(x, nbf_si, c = 'blue', alpha=0.5, label = 'sans interaction')
    plt.plot(x, nbf_pj, c = 'yellow', alpha=0.5, label = 'pub dirigée vers les jeunes')
    plt.plot(x, nbf_pv, c = 'grey', alpha=0.5, label = 'pub dirigée vers les plus de 30 ans')
    
    axes = plt.gca()
    axes.set_xlabel('Date')
    axes.set_ylabel('% de fumeur')
    plt.ylim(0,100)
    plt.xlim(2022,2022+nb_year)
    plt.xticks(np.linspace(2022,2022+nb_year,11))
    plt.legend()
    plt.show()

# %%
simulations(100,10,1)
